# %% [markdown]
# # Importing libraries

# %%
# import entrezpy.esearch.esearcher as esearcher
# import entrezpy.efetch.efetcher as efetcher

# %%
# import ensembl_rest
import requests
import cobra

# %% [markdown]
# # Loading SBML model

# %%
mitocore_mouse = cobra.io.read_sbml_model("Models/Mitocore_mouse.xml")

# %% [markdown]
# # Loading list of genes to test

# %%
# A file in .txt format with one gene symbol per line
txtfile = "genelist.txt"

# %%
# Creating list of genes to look for into the model
with open(txtfile, 'r') as genefile:
    gene_list = genefile.readlines()
gene_list = [gene.split('\n')[0] for gene in gene_list]

# %% [markdown]
# # Fetching synonyms

# %%
# NCBI API : Not working well
# def fetch_list_of_synonyms(gene_symbol):
#     print(f"Getting synonyms of {gene_symbol}")
#     es = esearcher.Esearcher('esearcher', 'email')
#     a = es.inquire({'db':'Gene', 'term':gene_symbol, 'retmax' : '10', 'rettype' : 'uilist'})
#     syn = [a.get_result().uids]
#     print(syn)
#     print(len(syn))
#     return syn

# %%
# Ensembl API : Missing some synonyms and no EC number available
# def get_synonyms(gene_symbol, dict_syn):
#     dict_syn[gene_symbol] = {}

#     request_synonyms = ensembl_rest.xref_name(
#             species='human',
#             name=gene_symbol
#         )
    
#     try:
#         request_id = ensembl_rest.symbol_lookup(
#                 species='human',
#                 symbol=gene_symbol
#             )
        
#         dict_syn[gene_symbol]['ensembl_id'] = request_id['id']

#     except:
#         print("No Ensembl ID found")
#         dict_syn[gene_symbol]['ensembl_id'] = ""
    
#     for dict_db in request_synonyms:
#         if dict_db['dbname'] == "HGNC":
#             dict_syn[gene_symbol]['synonyms'] = dict_db['synonyms']

# request = ensembl_rest.symbol_lookup(
#             species='human',
#             symbol="ACOX2"
#         )

# %%
# KEGG API, first step : operation FIND to look for KEGG entry access corresponding to a gene's symbol
# Get the entry for hsa organism (homo sapiens)
def get_entry_access(gene_symbol):
    url = "http://rest.kegg.jp/find/genes/"
    r = requests.get(url=url+gene_symbol)

    if r.status_code==200:
        info = str(r.content).split('\'')[1].split('\\n')[0].split('\\t')

        if info[0].split(':')[0] == 'hsa':
            entry_access = info[0]
            return entry_access
        
        print(f"Warning : no hsa entry access found for gene {gene_symbol}")
        return 0
    
    else: 
        print(f"Warning : gene {gene_symbol} is not found in kegg")

    return 0

# %%
# KEGG API, second step : operation GET to look for all info from a KEGG entry access corresponding to a gene's symbol
def get_all_info(entry_access, gene_symbol):
    if entry_access == 0:
        return 0
    
    url = "http://rest.kegg.jp/get/"
    r = requests.get(url=url+entry_access)

    if r.status_code==200:
        lines = str(r.content).split('\'')[1].split('\\n')
        dblink = False
        symbols = []
        ECNumber = 0
        ensembl_id = 0

        for line in lines:
            keyword = line.split(' ')[0]

            if keyword == "SYMBOL":
                symbols_line = line.split(' ')

                for s in symbols_line:
                    if s != 'SYMBOL' and s != '':
                        symbols.append(s)

            elif keyword == "ORTHOLOGY":
                if 'EC:' in line:
                    print(line)
                    ECNumber = line.split(':')[1].split(']')[0]
                else:
                    ECNumber = 0

            elif keyword == "DBLINKS":
                dblink = True

            elif dblink:
                if line.split(' ')[-2] == 'Ensembl:':
                    ensembl_id = line.split(' ')[-1]

                    return symbols, ECNumber, ensembl_id
    
    else:
        print(f"Warning : gene {gene_symbol} is not found in kegg")
    
    return 0

# %%
# Example for an access entry corresponding to ACOX2
get_all_info('hsa:8309', 'ACOX2')
# Out:
# ORTHOLOGY   K10214  3alpha,7alpha,12alpha-trihydroxy-5beta-cholestanoyl-CoA 24-hydroxylase [EC:1.17.99.3]
# (['ACOX2,', 'BCOX,', 'BRCACOX,', 'BRCOX,', 'CBAS6,', 'THCCox'],
#  '1.17.99.3',
#  'ENSG00000168306')

# %%
# dict_synonyms = {}

# for gene in gene_list:
#     print(f"Getting synonyms and Ensembl id for {gene}")
#     get_synonyms(gene, dict_synonyms)

# %%
# dict_synonyms = {}
# for gene in gene_list:
#         # dict_synonyms[gene] = fetch_list_of_synonyms(gene)
#         fetch_list_of_synonyms(gene)

# %%
def create_dict_synonyms(genes_list, dict_synonyms = {}):
    
    for gene in genes_list:
        # print(gene)
        entry = get_entry_access(gene)
        # print(entry)
        info = get_all_info(entry, gene)

        if info != 0:
            dict_synonyms[gene] = {'Synonyms': [syn.upper() for syn in info[0]], 'ECN': info[1], 'ensembl_id': info[2]}
        else:
            dict_synonyms[gene] = {'Synonyms': [gene.upper()], 'ECN': 0, 'ensembl_id': 0}
    
    return dict_synonyms

# %%
# Takes ~7min for 146 genes
dict_synonyms = create_dict_synonyms(gene_list)
# Out:
# ORTHOLOGY   K10214  3alpha,7alpha,12alpha-trihydroxy-5beta-cholestanoyl-CoA 24-hydroxylase [EC:1.17.99.3]
# ORTHOLOGY   K01895  acetyl-CoA synthetase [EC:6.2.1.1]
# ORTHOLOGY   K08618  a disintegrin and metalloproteinase with thrombospondin motifs 2 [EC:3.4.24.14]
# ORTHOLOGY   K00011  aldehyde reductase [EC:1.1.1.21]
# ORTHOLOGY   K00461  arachidonate 5-lipoxygenase [EC:1.13.11.34]
# ORTHOLOGY   K03766  beta-1,3-N-acetylglucosaminyltransferase 5 [EC:2.4.1.206]
# Warning : no hsa entry access found for gene Bglap2
# Warning : no hsa entry access found for gene BGN
# ORTHOLOGY   K15717  prostamide/prostaglandin F2alpha synthase [EC:1.11.1.20]
# Warning : no hsa entry access found for gene C2
# ORTHOLOGY   K07232  glutathione-specific gamma-glutamylcyclotransferase [EC:4.3.2.7]
# Warning : no hsa entry access found for gene CKB
# Warning : no hsa entry access found for gene Cox8b
# ORTHOLOGY   K08638  carboxypeptidase X1 [EC:3.4.17.-]
# Warning : no hsa entry access found for gene 2600001J17RIK
# Warning : no hsa entry access found for gene 3110007F17RIK
# Warning : no hsa entry access found for gene 5031425E22RIK
# Warning : no hsa entry access found for gene A730054J21RIK
# Warning : no hsa entry access found for gene A930016D02RIK
# Warning : no hsa entry access found for gene AW212394
# Warning : no hsa entry access found for gene CD40
# Warning : no hsa entry access found for gene EFS
# Warning : no hsa entry access found for gene GM1012
# ORTHOLOGY   K08784  HtrA serine peptidase 1 [EC:3.4.21.-]
# Warning : no hsa entry access found for gene KLRA18
# Warning : no hsa entry access found for gene LOC195357
# Warning : no hsa entry access found for gene LOC228790
# Warning : no hsa entry access found for gene LOC268393
# Warning : no hsa entry access found for gene LOC381283
# Warning : no hsa entry access found for gene PAPSS1
# Warning : no hsa entry access found for gene PLF
# Warning : no hsa entry access found for gene PLF2
# ORTHOLOGY   K16816  patatin-like phospholipase domain-containing protein 2 [EC:3.1.1.3]
# ORTHOLOGY   K08650  kallikrein 8 [EC:3.4.21.118]
# Warning : no hsa entry access found for gene SCL000959.1_2
# Warning : no hsa entry access found for gene SCT
# ORTHOLOGY   K14738  metalloreductase STEAP2 [EC:1.16.1.-]
# ORTHOLOGY   K10699  ubiquitin-activating enzyme E1-like protein 2 [EC:6.2.1.45]
# ORTHOLOGY   K09905  beta-1,4-galactosyltransferase 5 [EC:2.4.1.274 2.4.1.-]
# ORTHOLOGY   K07513  acetyl-CoA acyltransferase 1 [EC:2.3.1.16]
# Warning : no hsa entry access found for gene Acaalb
# ORTHOLOGY   K00626  acetyl-CoA C-acetyltransferase [EC:2.3.1.9]
# ORTHOLOGY   K01623  fructose-bisphosphate aldolase, class I [EC:4.1.2.13]
# Warning : no hsa entry access found for gene COX412
# Warning : no hsa entry access found for gene CPTIB
# ORTHOLOGY   K00658  2-oxoglutarate dehydrogenase E2 component (dihydrolipoamide succinyltransferase) [EC:2.3.1.61]
# ORTHOLOGY   K01084  glucose-6-phosphatase [EC:3.1.3.9]
# ORTHOLOGY   K00820  glutamine---fructose-6-phosphate transaminase (isomerizing) [EC:2.6.1.16]
# ORTHOLOGY   K08822  glycogen synthase kinase 3 alpha [EC:2.7.11.26]
# ORTHOLOGY   K00693  glycogen synthase [EC:2.4.1.11]
# ORTHOLOGY   K01892  histidyl-tRNA synthetase [EC:6.1.1.21]
# Warning : no hsa entry access found for gene LOC620306
# ORTHOLOGY   K03934  NADH dehydrogenase (ubiquinone) Fe-S protein 1 [EC:7.1.1.2]
# Warning : no hsa entry access found for gene NO01
# Warning : no hsa entry access found for gene OXGRI
# ORTHOLOGY   K09458  3-oxoacyl-[acyl-carrier-protein] synthase II [EC:2.3.1.179]
# ORTHOLOGY   K01596  phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32]
# ORTHOLOGY   K01103  6-phosphofructo-2-kinase / fructose-2,6-biphosphatase 3 [EC:2.7.1.105 3.1.3.46]
# Warning : no hsa entry access found for gene POR
# Warning : no hsa entry access found for gene SORDL
# Warning : no hsa entry access found for gene Timm8a2
# Warning : no hsa entry access found for gene Tmed11

# %% [markdown]
# # Model's Reactions

# %%
reactions_list = [reaction.id for reaction in mitocore_mouse.reactions]

# %%
def create_dict_model(model, reactions, final_dict = {}):
    reactions_wo_info = []
    ECn = []
    ids = []
    genes = []

    for reaction in reactions:
        notes = model.reactions.get_by_id(reaction).notes

        if ('EC Number' in notes) and (notes['EC Number'] != 'Unknown'):
            ECn = notes['EC Number'].split()
            ECn = [number for number in ECn if number not in ('or', 'and')]

        if ('GENE_ASSOCIATION' in notes) and (notes['GENE_ASSOCIATION'] != 'Unknown'):
            ids = notes['GENE_ASSOCIATION'].replace('(', '')
            ids = ids.replace(')', '')
            ids = ids.split()
            ids = [id for id in ids if id not in ('or', 'and')]

        if ('GENE_LIST' in notes) and (notes['GENE_LIST'] != 'Unknown'):
            genes = notes['GENE_LIST'].replace('(','')
            genes = genes.replace(')', '')
            genes = genes.split()
            genes = [gene.upper() for gene in genes if gene not in ('or', 'and')]

        if ECn == [] and id == [] and genes == []:
            reactions_wo_info.append(reaction)
            print(f"No information found, {reaction} is not added to dictionnary")
        else:
            final_dict[reaction] = {'ECN': ECn, 'ensembl_id': ids, 'genes': genes}

    return final_dict, reactions_wo_info

# %%
output = create_dict_model(mitocore_mouse, reactions_list)
names_to_check = output[1]
dict_model = output[0]

# %%
dict_model
# Out:
# {'EX_2hb_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_ac_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_acac_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_akg_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_ala_B_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_ala_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_arg_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_argsuc_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_asn_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_asp_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_bhb_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_bilirub_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_biomass_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_but_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_chol_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_cit_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_citr_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_co_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_co2_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_creat_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_cyan_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_cys_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_etoh_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_fe2_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_for_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_fum_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_glc_D_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_gln_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_glu_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_gly_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_glyc_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_h_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_h2o_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_HC00250_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_hco3_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_hdca_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_his_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_icit_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_ile_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_lac_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_leu_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_lys_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_mal_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_mercplac_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_met_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_nad_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_nadh_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_nh4_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_no_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_o2_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_oaa_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_pchol_hs_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_pcreat_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_pe_hs_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_phe_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_pi_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_ppa_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_pro_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_ps_hs_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_ser_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_so3_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_succ_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_tcynt_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_thr_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_trp_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_tsul_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_tyr_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_urea_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_val_L_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'EX_fol_e': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'OF_ATP_MitoCore': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'OF_HEME_MitoCore': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'OF_LIPID_MitoCore': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'OF_PROTEIN_MitoCore': {'ECN': [], 'ensembl_id': [], 'genes': []},
#  'HEX1': {'ECN': ['2.7.1.1', '2.7.1.2'],
#   'ensembl_id': ['ENSG00000156515',
#    'ENSG00000159399',
#    'ENSG00000160883',
#    'ENSG00000106633'],
#   'genes': ['HK1', 'HK2', 'HK3', 'GCK']},
#  'G6PPer': {'ECN': ['3.1.3.9'],
#   'ensembl_id': ['ENSG00000131482'],
#   'genes': ['G6PC']},
#  'PGI': {'ECN': ['5.3.1.9'],
#   'ensembl_id': ['ENSG00000105220'],
#   'genes': ['GPI']},
#  'PFK': {'ECN': ['2.7.1.11'],
#   'ensembl_id': ['ENSG00000152556'],
#   'genes': ['PFKM']},
#  'FBP': {'ECN': ['3.1.3.11'],
#   'ensembl_id': ['ENSG00000165140', 'ENSG00000130957'],
#   'genes': ['FBP1', 'FBP2']},
#  'FBA': {'ECN': ['4.1.2.13'],
#   'ensembl_id': ['ENSG00000149925', 'ENSG00000109107'],
#   'genes': ['ALDOA', 'ALDOC']},
#  'TPI': {'ECN': ['5.3.1.1'],
#   'ensembl_id': ['ENSG00000111669'],
#   'genes': ['TPI1']},
#  'GAPD': {'ECN': ['1.2.1.12'],
#   'ensembl_id': ['ENSG00000111640'],
#   'genes': ['GAPDH']},
#  'PGK': {'ECN': ['2.7.2.3'],
#   'ensembl_id': ['ENSG00000102144'],
#   'genes': ['PGK1']},
#  'PGM': {'ECN': ['5.4.2.1'],
#   'ensembl_id': ['ENSG00000171314', 'ENSG00000164708'],
#   'genes': ['PGAM1', 'PGAM2']},
#  'ENO': {'ECN': ['4.2.1.11'],
#   'ensembl_id': ['ENSG00000074800', 'ENSG00000111674', 'ENSG00000108515'],
#   'genes': ['ENO1', 'ENO2', 'ENO3']},
#  'PYK': {'ECN': ['2.7.1.40'],
#   'ensembl_id': ['ENSG00000067225'],
#   'genes': ['PKM']},
#  'r0122': {'ECN': ['2.7.1.40'],
#   'ensembl_id': ['ENSG00000067225'],
#   'genes': ['PKM']},
#  'PEPCK': {'ECN': ['4.1.1.32'],
#   'ensembl_id': ['ENSG00000124253'],
#   'genes': ['PCK1']},
#  'LDH_L': {'ECN': ['1.1.1.27'],
#   'ensembl_id': ['ENSG00000111716'],
#   'genes': ['LDHB']},
#  'G6PDH2r': {'ECN': ['1.1.1.49'],
#   'ensembl_id': ['ENSG00000160211'],
#   'genes': ['G6PD']},
#  'PGL': {'ECN': ['3.1.1.31'],
#   'ensembl_id': ['ENSG00000130313'],
#   'genes': ['PGLS']},
#  'GND': {'ECN': ['1.1.1.44'],
#   'ensembl_id': ['ENSG00000142657'],
#   'genes': ['PGD']},
#  'RPI': {'ECN': ['5.3.1.6'],
#   'ensembl_id': ['ENSG00000153574'],
#   'genes': ['RPIA']},
#  'RPE': {'ECN': ['5.1.3.1'],
#   'ensembl_id': ['ENSG00000235376'],
#   'genes': ['RPEL1']},
#  'TKT1': {'ECN': ['2.2.1.1'],
#   'ensembl_id': ['ENSG00000163931'],
#   'genes': ['TKT']},
#  'TALA': {'ECN': ['2.2.1.2'],
#   'ensembl_id': ['ENSG00000177156'],
#   'genes': ['TALDO1']},
#  'TKT2': {'ECN': ['2.2.1.1'],
#   'ensembl_id': ['ENSG00000163931'],
#   'genes': ['TKT']},
#  'PDHm': {'ECN': ['1.2.4.1,', '2.3.1.12,', '1.8.1.4'],
#   'ensembl_id': ['ENSG00000131828',
#    'ENSG00000168291',
#    'ENSG00000150768',
#    'ENSG00000091140'],
#   'genes': ['PDHA1', 'PDHB', 'DLAT', 'DLD']},
#  'CSm': {'ECN': ['2.3.3.1'],
#   'ensembl_id': ['ENSG00000062485'],
#   'genes': ['CS']},
#  'ACONTm': {'ECN': ['4.2.1.3'],
#   'ensembl_id': ['ENSG00000100412'],
#   'genes': ['ACO2']},
#  'ICDHxm': {'ECN': ['1.1.1.41'],
#   'ensembl_id': ['ENSG00000166411', 'ENSG00000101365', 'ENSG00000067829'],
#   'genes': ['IDH3A', 'IDH3B', 'IDH3G']},
#  'ICDHyrm': {'ECN': ['1.1.1.42'],
#   'ensembl_id': ['ENSG00000182054'],
#   'genes': ['IDH2']},
#  'AKGDm': {'ECN': ['1.2.4.2,', '1.8.1.4,', '2.3.1.61'],
#   'ensembl_id': ['ENSG00000105953', 'ENSG00000119689', 'ENSG00000091140'],
#   'genes': ['OGDH', 'DLST', 'DLD']},
#  'SUCOAS1m': {'ECN': ['6.2.1.4'],
#   'ensembl_id': ['ENSG00000163541', 'ENSG00000172340'],
#   'genes': ['SUCLG1', 'SUCLG2']},
#  'SUCOASm': {'ECN': ['6.2.1.5'],
#   'ensembl_id': ['ENSG00000136143'],
#   'genes': ['SUCLA2']},
#  'FUMm': {'ECN': ['4.2.1.2'],
#   'ensembl_id': ['ENSG00000091483'],
#   'genes': ['FH']},
#  'MDHm': {'ECN': ['1.1.1.37'],
#   'ensembl_id': ['ENSG00000146701'],
#   'genes': ['MDH2']},
#  'CI_MitoCore': {'ECN': ['1.6.5.3,', '1.6.5.8,', '1.6.5.9'],
#   'ensembl_id': ['ENSG00000115286',
#    'ENSG00000110717',
#    'ENSG00000178127',
#    'ENSG00000213619',
#    'ENSG00000158864',
#    'ENSG00000167792',
#    'ENSG00000023228',
#    'ENSG00000198888',
#    'ENSG00000198763',
#    'ENSG00000198840',
#    'ENSG00000198886',
#    'ENSG00000212907',
#    'ENSG00000198786',
#    'ENSG00000198695',
#    'ENSG00000145494',
#    'ENSG00000184752',
#    'ENSG00000164258',
#    'ENSG00000139180',
#    'ENSG00000004779',
#    'ENSG00000131495',
#    'ENSG00000119013',
#    'ENSG00000128609',
#    'ENSG00000184983',
#    'ENSG00000174886',
#    'ENSG00000147123',
#    'ENSG00000168653',
#    'ENSG00000065518',
#    'ENSG00000186010',
#    'ENSG00000099795',
#    'ENSG00000119421',
#    'ENSG00000147684',
#    'ENSG00000140990',
#    'ENSG00000166136',
#    'ENSG00000151366',
#    'ENSG00000090266',
#    'ENSG00000267855',
#    'ENSG00000170906',
#    'ENSG00000189043',
#    'ENSG00000136521',
#    'ENSG00000183648',
#    'ENSG00000109390',
#    'ENSG00000130414',
#    'ENSG00000185633',
#    'ENSG00000160194',
#    'ENSG00000165264'],
#   'genes': ['NDUFS7',
#    'NDUFS8',
#    'NDUFV2',
#    'NDUFS3',
#    'NDUFS2',
#    'NDUFV1',
#    'NDUFS1',
#    'MT-ND1',
#    'MT-ND2',
#    'MT-ND3',
#    'MT-ND4',
#    'MT-ND4L',
#    'MT-ND5',
#    'MT-ND6',
#    'NDUFS6',
#    'NDUFA12',
#    'NDUFS4',
#    'NDUFA9',
#    'NDUFAB1',
#    'NDUFA2',
#    'NDUFB3',
#    'NDUFA5',
#    'NDUFA6',
#    'NDUFA11',
#    'NDUFB11',
#    'NDUFS5',
#    'NDUFB4',
#    'NDUFA13',
#    'NDUFB7',
#    'NDUFA8',
#    'NDUFB9',
#    'NDUFB10',
#    'NDUFB8',
#    'NDUFC2',
#    'NDUFB2',
#    'NDUFA7',
#    'NDUFA3',
#    'NDUFA4',
#    'NDUFB5',
#    'NDUFB1',
#    'NDUFC1',
#    'NDUFA10',
#    'NDUFA4L2',
#    'NDUFV3',
#    'NDUFB6']},
#  'CII_MitoCore': {'ECN': ['1.3.5.1'],
#   'ensembl_id': ['ENSG00000073578', 'ENSG00000117118', 'ENSG00000143252'],
#   'genes': ['SDHA', 'SDHB', 'SDHC']},
#  'CIII_MitoCore': {'ECN': ['1.10.2.2'],
#   'ensembl_id': ['ENSG00000198727',
#    'ENSG00000179091',
#    'ENSG00000172115',
#    'ENSG00000169021',
#    'ENSG00000156467',
#    'ENSG00000173660',
#    'ENSG00000140740',
#    'ENSG00000010256',
#    'ENSG00000127540',
#    'ENSG00000184076',
#    'ENSG00000011295'],
#   'genes': ['MT-CYB',
#    'CYC1',
#    'CYCS',
#    'UQCRFS1',
#    'UQCRB',
#    'UQCRH',
#    'UQCRC2',
#    'UQCRC1',
#    'UQCR11',
#    'UQCR10',
#    'TTC19']},
#  'CIV_MitoCore': {'ECN': ['1.9.3.1'],
#   'ensembl_id': ['ENSG00000198804',
#    'ENSG00000198712',
#    'ENSG00000198938',
#    'ENSG00000131143',
#    'ENSG00000131055',
#    'ENSG00000178741',
#    'ENSG00000135940',
#    'ENSG00000111775',
#    'ENSG00000156885',
#    'ENSG00000126267',
#    'ENSG00000160471',
#    'ENSG00000164919',
#    'ENSG00000161281',
#    'ENSG00000112695',
#    'ENSG00000115944',
#    'ENSG00000131174',
#    'ENSG00000127184',
#    'ENSG00000115944',
#    'ENSG00000176340',
#    'ENSG00000187581'],
#   'genes': ['MT-CO1',
#    'MT-CO2',
#    'MT-CO3',
#    'COX4I1',
#    'COX4I2',
#    'COX5A',
#    'COX5B',
#    'COX6A1',
#    'COX6A2',
#    'COX6B1',
#    'COX6B2',
#    'COX6C',
#    'COX7A1',
#    'COX7A2',
#    'COX7A2L',
#    'COX7B',
#    'COX7C',
#    'COX7A2L',
#    'COX8A',
#    'COX8C']},
#  'CV_MitoCore': {'ECN': ['3.6.3.14,', '3.6.3.10,', '3.6.3.6'],
#   'ensembl_id': ['ENSG00000152234',
#    'ENSG00000110955',
#    'ENSG00000165629',
#    'ENSG00000099624',
#    'ENSG00000124172',
#    'ENSG00000116459',
#    'ENSG00000159199',
#    'ENSG00000135390',
#    'ENSG00000154518',
#    'ENSG00000167863',
#    'ENSG00000169020',
#    'ENSG00000154723',
#    'ENSG00000241468',
#    'ENSG00000167283',
#    'ENSG00000249222',
#    'ENSG00000241837',
#    'ENSG00000198899',
#    'ENSG00000228253'],
#   'genes': ['ATP5A1',
#    'ATP5B',
#    'ATP5C1',
#    'ATP5D',
#    'ATP5E',
#    'ATP5F1',
#    'ATP5G1',
#    'ATP5G2',
#    'ATP5G3',
#    'ATP5H',
#    'ATP5I',
#    'ATP5J',
#    'ATP5J2',
#    'ATP5L',
#    'ATP5L2',
#    'ATP5O',
#    'MT-ATP6',
#    'MT-ATP8']},
#  'PEPCKm': {'ECN': ['4.1.1.32'],
#   'ensembl_id': ['ENSG00000100889'],
#   'genes': ['PCK2']},
#  'PCm': {'ECN': ['6.4.1.1'],
#   'ensembl_id': ['ENSG00000173599'],
#   'genes': ['PC']},
#  'ME2m': {'ECN': ['1.1.1.40'],
#   'ensembl_id': ['ENSG00000151376'],
#   'genes': ['ME3']},
#  'ME1m': {'ECN': ['1.1.1.38'],
#   'ensembl_id': ['ENSG00000082212'],
#   'genes': ['ME2']},
#  'r0081': {'ECN': ['2.6.1.2'],
#   'ensembl_id': ['ENSG00000166123'],
#   'genes': ['GPT2']},
#  'ACITLm_MitoCore': {'ECN': ['2.3.3.8'],
#   'ensembl_id': ['ENSG00000131473'],
#   'genes': ['ACLY']},
#  'NDPK1m': {'ECN': ['2.7.4.6'],
#   'ensembl_id': ['ENSG00000103202'],
#   'genes': ['NME4']},
#  'NNT_MitoCore': {'ECN': ['1.6.1.2'],
#   'ensembl_id': ['ENSG00000112992'],
#   'genes': ['NNT']},
#  'ADK1m': {'ECN': ['2.7.4.3'],
#   'ensembl_id': ['ENSG00000004455', 'ENSG00000147853'],
#   'genes': ['AK2', 'AK3']},
#  'ME2': {'ECN': ['1.1.1.40'],
#   'ensembl_id': ['ENSG00000065833'],
#   'genes': ['ME1']},
#  'ALATA_L': {'ECN': ['2.6.1.2'],
#   'ensembl_id': ['ENSG00000167701'],
#   'genes': ['GPT']},
#  'NDPK1': {'ECN': ['2.7.4.6'],
#   'ensembl_id': ['ENSG00000011052',
#    'ENSG00000103024',
#    'ENSG00000172113',
#    'ENSG00000143156',
#    'ENSG00000162368',
#    'ENSG00000106992',
#    'ENSG00000162433',
#    'ENSG00000154027',
#    'ENSG00000140057',
#    'ENSG00000165695',
#    'ENSG00000155085'],
#   'genes': ['NME2',
#    'NME3',
#    'NME6',
#    'NME7',
#    'CMPK1',
#    'AK1',
#    'AK4',
#    'AK5',
#    'AK7',
#    'AK8',
#    'AK9']},
#  'FUM': {'ECN': ['4.2.1.2'],
#   'ensembl_id': ['ENSG00000091483'],
#   'genes': ['FH']},
#  'ADK1': {'ECN': ['2.7.4.3'],
#   'ensembl_id': ['ENSG00000106992'],
#   'genes': ['AK1']},
#  'ICDHy': {'ECN': ['1.1.1.42'],
#   'ensembl_id': ['ENSG00000138413'],
#   'genes': ['IDH1']},
#  'ACONT': {'ECN': ['4.2.1.3'],
#   'ensembl_id': ['ENSG00000122729'],
#   'genes': ['ACO1']},
#  'ACITL': {'ECN': ['2.3.3.8'],
#   'ensembl_id': ['ENSG00000131473'],
#   'genes': ['ACLY']},
#  'ASPTA': {'ECN': ['2.6.1.1'],
#   'ensembl_id': ['ENSG00000120053'],
#   'genes': ['GOT1']},
#  'MDH': {'ECN': ['1.1.1.37'],
#   'ensembl_id': ['ENSG00000014641'],
#   'genes': ['MDH1']},
#  'AKGMALtm': {'ECN': ['N/A'],
#   'ensembl_id': ['ENSG00000108528'],
#   'genes': ['SLC25A11']},
#  'ASPGLUmB_MitoCore': {'ECN': ['N/A'],
#   'ensembl_id': ['ENSG00000115840', 'ENSG00000004864'],
#   'genes': ['SLC25A12', 'SLC25A13']},
#  'ASPTAm': {'ECN': ['2.6.1.1'],
#   'ensembl_id': ['ENSG00000125166'],
#   'genes': ['GOT2']},
#  'G3PD1': {'ECN': ['1.1.1.8'],
#   'ensembl_id': ['ENSG00000167588', 'ENSG00000152642'],
#   'genes': ['GPD1', 'GPD1L']},
#  'r0205': {'ECN': ['1.1.5.3'],
#   'ensembl_id': ['ENSG00000115159'],
#   'genes': ['GPD2']},
#  'FACOAL160i': {'ECN': ['6.2.1.3'],
#   'ensembl_id': ['ENSG00000151726',
#    'ENSG00000123983',
#    'ENSG00000068366',
#    'ENSG00000103740',
#    'ENSG00000164398',
#    'ENSG00000197142',
#    'ENSG00000130377'],
#   'genes': ['ACSL1', 'ACSL3', 'ACSL4', 'ACSBG1', 'ACSL6', 'ACSL5', 'ACSBG2']},
#  'C160CPT1': {'ECN': ['2.3.1.21'],
#   'ensembl_id': ['ENSG00000205560'],
#   'genes': ['CPT1B']},
#  'PPA': {'ECN': ['3.6.1.1'],
#   'ensembl_id': ['ENSG00000180817'],
#   'genes': ['PPA1']},
#  'r2435': {'ECN': ['N/A'],
#   'ensembl_id': ['ENSG00000178537'],
#   'genes': ['SLC25A20']},
#  'C160CPT2': {'ECN': ['2.3.1.21'],
#   'ensembl_id': ['ENSG00000157184'],
#   'genes': ['CPT2']},
#  'PPAm': {'ECN': ['3.6.1.1'],
#   'ensembl_id': ['ENSG00000138777'],
#   'genes': ['PPA2']},
#  'ACOT2_MitoCore': {'ECN': ['3.1.2.2'],
#   'ensembl_id': ['ENSG00000119673'],
#   'genes': ['ACOT2']},
#  'ACADLC16_MitoCore': {'ECN': ['1.3.8.8,', '1.5.5.1'],
#   'ensembl_id': ['ENSG00000115361', 'ENSG00000171503'],
#   'genes': ['ACADL', 'ETFDH']},
#  'MECR16C_MitoCore': {'ECN': ['1.3.1.38'],
#   'ensembl_id': ['ENSG00000116353'],
#   'genes': ['MECR']},
#  'MTPC16_MitoCore': {'ECN': ['4.2.1.74,', '1.1.1.211,', '2.3.1.16'],
#   'ensembl_id': ['ENSG00000084754', 'ENSG00000138029'],
#   'genes': ['HADHA', 'HADHB']},
#  'ACADLC14_MitoCore': {'ECN': ['1.3.8.8,', '1.5.5.1'],
#   'ensembl_id': ['ENSG00000115361', 'ENSG00000171503'],
#   'genes': ['ACADL', 'ETFDH']},
#  'MECR14C_MitoCore': {'ECN': ['1.3.1.38'],
#   'ensembl_id': ['ENSG00000116353'],
#   'genes': ['MECR']},
#  'MTPC14_MitoCore': {'ECN': ['4.2.1.74,', '1.1.1.211,', '2.3.1.16'],
#   'ensembl_id': ['ENSG00000084754', 'ENSG00000138029'],
#   'genes': ['HADHA', 'HADHB']},
#  'r1447': {'ECN': ['1.3.8.7,', '1.5.5.1'],
#   'ensembl_id': ['ENSG00000117054', 'ENSG00000171503'],
#   'genes': ['ACADM', 'ETFDH']},
#  'r0638': {'ECN': ['1.3.1.38'],
#   'ensembl_id': ['ENSG00000116353'],
#   'genes': ['MECR']},
#  'r0660': {'ECN': ['4.2.1.17'],
#   'ensembl_id': ['ENSG00000127884'],
#   'genes': ['ECHS1']},
#  'r0722': {'ECN': ['1.1.1.35'],
#   'ensembl_id': ['ENSG00000138796'],
#   'genes': ['HADH']},
#  'r0724': {'ECN': ['2.3.1.16'],
#   'ensembl_id': ['ENSG00000167315'],
#   'genes': ['ACAA2']},
#  'r1451': {'ECN': ['1.3.8.7,', '1.5.5.1'],
#   'ensembl_id': ['ENSG00000117054', 'ENSG00000171503'],
#   'genes': ['ACADM', 'ETFDH']},
#  'r0735': {'ECN': ['1.3.1.38'],
#   'ensembl_id': ['ENSG00000116353'],
#   'genes': ['MECR']},
#  'r0728': {'ECN': ['4.2.1.17'],
#   'ensembl_id': ['ENSG00000127884'],
#   'genes': ['ECHS1']},
#  'r0726': {'ECN': ['1.1.1.35'],
#   'ensembl_id': ['ENSG00000138796'],
#   'genes': ['HADH']},
#  'r0634': {'ECN': ['2.3.1.16'],
#   'ensembl_id': ['ENSG00000167315'],
#   'genes': ['ACAA2']},
#  'r1448': {'ECN': ['1.3.8.7,', '1.5.5.1'],
#   'ensembl_id': ['ENSG00000117054', 'ENSG00000171503'],
#   'genes': ['ACADM', 'ETFDH']},
#  'r0633': {'ECN': ['1.3.1.38'],
#   'ensembl_id': ['ENSG00000116353'],
#   'genes': ['MECR']},
#  'r0731': {'ECN': ['4.2.1.17'],
#   'ensembl_id': ['ENSG00000127884'],
#   'genes': ['ECHS1']},
#  'r0730': {'ECN': ['1.1.1.35'],
#   'ensembl_id': ['ENSG00000138796'],
#   'genes': ['HADH']},
#  'r0732': {'ECN': ['2.3.1.16'],
#   'ensembl_id': ['ENSG00000167315'],
#   'genes': ['ACAA2']},
#  'r1450': {'ECN': ['1.3.8.7,', '1.5.5.1'],
#   'ensembl_id': ['ENSG00000117054', 'ENSG00000171503'],
#   'genes': ['ACADM', 'ETFDH']},
#  'r0791': {'ECN': ['1.3.1.38'],
#   'ensembl_id': ['ENSG00000116353'],
#   'genes': ['MECR']},
#  'r0734': {'ECN': ['4.2.1.17'],
#   'ensembl_id': ['ENSG00000127884'],
#   'genes': ['ECHS1']},
#  'r0733': {'ECN': ['1.1.1.35'],
#   'ensembl_id': ['ENSG00000138796'],
#   'genes': ['HADH']},
#  'r0287': {'ECN': ['2.3.1.16'],
#   'ensembl_id': ['ENSG00000167315'],
#   'genes': ['ACAA2']},
#  'r1446': {'ECN': ['1.3.8.1,', '1.5.5.1'],
#   'ensembl_id': ['ENSG00000122971', 'ENSG00000171503'],
#   'genes': ['ACADS', 'ETFDH']},
#  'ECOAH1m': {'ECN': ['4.2.1.17'],
#   'ensembl_id': ['ENSG00000127884'],
#   'genes': ['ECHS1']},
#  'HACD1m': {'ECN': ['1.1.1.35'],
#   'ensembl_id': ['ENSG00000138796'],
#   'genes': ['HADH']},
#  'ACACT1rm': {'ECN': ['2.3.1.9'],
#   'ensembl_id': ['ENSG00000075239'],
#   'genes': ['ACAT1']},
#  'ACCOAC': {'ECN': ['6.4.1.2'],
#   'ensembl_id': ['ENSG00000278540', 'ENSG00000076555'],
#   'genes': ['ACACA', 'ACACB']},
#  'MCOATA': {'ECN': ['2.3.1.39'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'ACOATA': {'ECN': ['2.3.1.38'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0678': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0691': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0681': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0682': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0760': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0761': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0762': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0763': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0764': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0694': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0695': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0765': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0766': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0692': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0693': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0767': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0768': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0769': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0770': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0712': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0713': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0701': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0702': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0771': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0772': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0696': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0697': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'r0773': {'ECN': ['2.3.1.85'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'FA160ACPH': {'ECN': ['3.1.2.14'],
#   'ensembl_id': ['ENSG00000169710'],
#   'genes': ['FASN']},
#  'FACOAL40im': {'ECN': ['6.2.1.2'],
#   'ensembl_id': ['ENSG00000005187', 'ENSG00000173124'],
#   'genes': ['ACSM3', 'ACSM6']},
#  'BDHm': {'ECN': ['1.1.1.30'],
#   'ensembl_id': ['ENSG00000161267'],
#   'genes': ['BDH1']},
#  'OCOAT1m': {'ECN': ['2.8.3.5'],
#   'ensembl_id': ['ENSG00000083720'],
#   'genes': ['OXCT1']},
#  'HMGCOASim': {'ECN': ['2.3.3.10'],
#   'ensembl_id': ['ENSG00000134240'],
#   'genes': ['HMGCS2']},
#  'HMGLm': {'ECN': ['4.1.3.4'],
#   'ensembl_id': ['ENSG00000117305'],
#   'genes': ['HMGCL']},
#  'LEUTAm': {'ECN': ['2.6.1.42'],
#   'ensembl_id': ['ENSG00000105552'],
#   'genes': ['42542']},
#  'OIVD1m': {'ECN': ['1.2.4.4,', '2.3.1.168,', '1.8.1.4'],
#   'ensembl_id': ['ENSG00000248098',
#    'ENSG00000083123',
#    'ENSG00000137992',
#    'ENSG00000091140'],
#   'genes': ['BCKDHA', 'BCKDHB', 'DBT', 'DLD']},
#  'r0655': {'ECN': ['1.3.8.4'],
#   'ensembl_id': ['ENSG00000128928'],
#   'genes': ['IVD']},
#  'MCCCrm': {'ECN': ['6.4.1.4'],
#   'ensembl_id': ['ENSG00000078070', 'ENSG00000131844'],
#   'genes': ['MCCC1', 'MCCC2']},
#  'MGCHrm': {'ECN': ['4.2.1.18'],
#   'ensembl_id': ['ENSG00000148090'],
#   'genes': ['AUH']},
#  'ILETAm': {'ECN': ['2.6.1.42'],
#   'ensembl_id': ['ENSG00000105552'],
#   'genes': ['BCAT2']},
#  'OIVD3m': {'ECN': ['1.2.4.4,', '2.3.1.168,', '1.8.1.4'],
#   'ensembl_id': ['ENSG00000248098',
#    'ENSG00000083123',
#    'ENSG00000137992',
#    'ENSG00000091140'],
#   'genes': ['BCKDHA', 'BCKDHB', 'DBT', 'DLD']},
#  'r0603': {'ECN': ['1.3.8.1'],
#   'ensembl_id': ['ENSG00000122971'],
#   'genes': ['ACADS']},
#  'ECOAH9m': {'ECN': ['4.2.1.17'],
#   'ensembl_id': ['ENSG00000127884'],
#   'genes': ['ECHS1']},
#  'HACD9m': {'ECN': ['1.1.1.35'],
#   'ensembl_id': ['ENSG00000138796'],
#   'genes': ['HADH']},
#  'ACACT10m': {'ECN': ['2.3.1.16'],
#   'ensembl_id': ['ENSG00000167315'],
#   'genes': ['ACAA2']},
#  'VALTAm': {'ECN': ['2.6.1.42'],
#   'ensembl_id': ['ENSG00000105552'],
#   'genes': ['BCAT2']},
#  'OIVD2m': {'ECN': ['1.2.4.4,', '2.3.1.168,', '1.8.1.4'],
#   'ensembl_id': ['ENSG00000248098',
#    'ENSG00000083123',
#    'ENSG00000137992',
#    'ENSG00000091140'],
#   'genes': ['BCKDHA', 'BCKDHB', 'DBT', 'DLD']},
#  'r0560': {'ECN': ['1.3.8.1'],
#   'ensembl_id': ['ENSG00000122971'],
#   'genes': ['ACADS']},
#  'ECOAH12m': {'ECN': ['4.2.1.17'],
#   'ensembl_id': ['ENSG00000127884'],
#   'genes': ['ECHS1']},
#  '3HBCOAHLm': {'ECN': ['3.2.1.4'],
#   'ensembl_id': ['ENSG00000198130'],
#   'genes': ['HIBCH']},
#  'HIBDm': {'ECN': ['1.1.1.31', '1.1.1.35'],
#   'ensembl_id': ['ENSG00000106049', 'ENSG00000138796'],
#   'genes': ['HIBADH', 'HADH']},
#  'ACCOALm': {'ECN': ['6.2.1.1'],
#   'ensembl_id': ['ENSG00000111058'],
#   'genes': ['ACSS3']},
#  'MMSAD1m': {'ECN': ['1.2.1.27'],
#   'ensembl_id': ['ENSG00000119711'],
#   'genes': ['ALDH6A1']},
#  'PPCOACm': {'ECN': ['6.4.1.3'],
#   'ensembl_id': ['ENSG00000175198', 'ENSG00000114054'],
#   'genes': ['PCCA', 'PCCB']},
#  'MMEm': {'ECN': ['5.1.99.1'],
#   'ensembl_id': ['ENSG00000124370'],
#   'genes': ['MCEE']},
#  'MMMm': {'ECN': ['5.4.99.2'],
#   'ensembl_id': ['ENSG00000146085'],
#   'genes': ['MUT']},
#  'MMCDm': {'ECN': ['4.1.1.41'],
#   'ensembl_id': ['ENSG00000093144'],
#   'genes': ['ECHDC1']},
#  'RE2649M': {'ECN': ['3.1.2.2'],
#   'ensembl_id': ['ENSG00000119673'],
#   'genes': ['ACOT2']},
#  'THRD_L': {'ECN': ['4.3.1.19'],
#   'ensembl_id': ['ENSG00000135094', 'ENSG00000139410'],
#   'genes': ['SDS', 'SDSL']},
#  'r1155': {'ECN': ['N/A'],
#   'ensembl_id': ['ENSG00000135094', 'ENSG00000139410'],
#   'genes': ['SDS', 'SDSL']},
#  'r1154': {'ECN': ['1.2.4.4', '+', '2.3.1.168', '+', '1.8.1.4'],
#   'ensembl_id': ['ENSG00000248098',
#    'ENSG00000083123',
#    'ENSG00000137992',
#    'ENSG00000091140'],
#   'genes': ['BCKDHA', 'BCKDHB', 'DBT', 'DLD']},
#  '2HBO': {'ECN': ['1.1.1.27'],
#   'ensembl_id': ['ENSG00000111716'],
#   'genes': ['LDHB']},
#  'METAT': {'ECN': ['2.5.1.6'],
#   'ensembl_id': ['ENSG00000168906'],
#   'genes': ['MAT2A']},
#  'METAT2_MitoCore': {'ECN': ['2.1.1.-'],
#   'ensembl_id': ['N/A'],
#   'genes': ['N/A']},
#  'AHC': {'ECN': ['3.3.1.1'],
#   'ensembl_id': ['ENSG00000101444', 'ENSG00000168710', 'ENSG00000158467'],
#   'genes': ['AHCY', 'AHCYL1', 'AHCYL2']},
#  'ADNK1': {'ECN': ['2.7.1.20'],
#   'ensembl_id': ['ENSG00000156110'],
#   'genes': ['ADK']},
#  'CYSTS': {'ECN': ['4.2.1.22'],
#   'ensembl_id': ['ENSG00000160200'],
#   'genes': ['CBS']},
#  'CYSTGL': {'ECN': ['4.4.1.1'],
#   'ensembl_id': ['ENSG00000116761'],
#   'genes': ['CTH']},
#  'CYSO': {'ECN': ['1.13.11.20'],
#   'ensembl_id': ['ENSG00000129596'],
#   'genes': ['CDO1']},
#  '3SALATAi': {'ECN': ['2.6.1.1'],
#   'ensembl_id': ['ENSG00000120053'],
#   'genes': ['GOT1']},
#  '3SPYRSP': {'ECN': ['Non-Enzymatic'],
#   'ensembl_id': ['Non-Enzymatic'],
#   'genes': ['NON-ENZYMATIC']},
#  'CYSTA': {'ECN': ['2.6.1.1'],
#   'ensembl_id': ['ENSG00000120053'],
#   'genes': ['GOT1']},
#  'CYSTAm': {'ECN': ['2.6.1.1'],
#   'ensembl_id': ['ENSG00000125166'],
#   'genes': ['GOT2']},
#  'MCPST': {'ECN': ['2.8.1.2'],
#   'ensembl_id': ['ENSG00000128309'],
#   'genes': ['MPST']},
#  'MCPSTm_MitoCore': {'ECN': ['2.8.1.2'],
#   'ensembl_id': ['ENSG00000128309'],
#   'genes': ['MPST']},
#  'r0595m_MitoCore': {'ECN': ['2.8.1.2'],
#   'ensembl_id': ['ENSG00000128309'],
#   'genes': ['MPST']},
#  'r0595B_MitoCore': {'ECN': ['2.8.1.2'],
#   'ensembl_id': ['ENSG00000128309'],
#   'genes': ['MPST']},
#  'MCLOR': {'ECN': ['1.1.1.27'],
#   'ensembl_id': ['ENSG00000111716'],
#   'genes': ['LDHB']},
#  'r0193': {'ECN': ['4.4.1.1'],
#   'ensembl_id': ['ENSG00000116761'],
#   'genes': ['CTH']},
#  'TRPO2': {'ECN': ['1.13.11.11', '1.13.11.52'],
#   'ensembl_id': ['ENSG00000151790', 'ENSG00000131203'],
#   'genes': ['TDO2', 'IDO1']},
#  'FKYNH': {'ECN': ['3.5.1.9'],
#   'ensembl_id': ['ENSG00000183077'],
#   'genes': ['AFMID']},
#  'KYN3OX': {'ECN': ['1.14.13.9'],
#   'ensembl_id': ['ENSG00000117009'],
#   'genes': ['KMO']},
#  'HKYNH': {'ECN': ['3.7.1.3'],
#   'ensembl_id': ['ENSG00000115919'],
#   'genes': ['KYNU']},
#  '3HAO': {'ECN': ['1.13.11.6'],
#   'ensembl_id': ['ENSG00000162882'],
#   'genes': ['HAAO']},
#  'PCLAD': {'ECN': ['4.1.1.45'],
#   'ensembl_id': ['ENSG00000153086'],
#   'genes': ['ACMSD']},
#  'r0645': {'ECN': ['1.2.1.32'],
#   'ensembl_id': ['ENSG00000153086'],
#   'genes': ['ACMSD']},
#  'AMCOXO': {'ECN': ['1.5.1.-'],
#   'ensembl_id': ['ENSG00000153086'],
#   'genes': ['ACMSD']},
#  'AMCOXO2_MitoCore': {'ECN': ['1.5.1.-'],
#   'ensembl_id': ['ENSG00000153086'],
#   'genes': ['ACMSD']},
#  '2OXOADPTmB_MitoCore': {'ECN': ['n/a'],
#   'ensembl_id': ['ENSG00000183032'],
#   'genes': ['SLC25A21']},
#  '2OXOADPTmC_MitoCore': {'ECN': ['n/a'],
#   'ensembl_id': ['ENSG00000183032'],
#   'genes': ['SLC25A21']},
#  '2OXOADOXm': {'ECN': ['1.2.4.2', '2.3.1.61', '1.8.1.4'],
#   'ensembl_id': ['ENSG00000105953', 'ENSG00000119689', 'ENSG00000091140'],
#   'genes': ['OGDH', 'DLST', 'DLD']},
#  'r0541': {'ECN': ['1.3.8.6'],
#   'ensembl_id': ['ENSG00000105607'],
#   'genes': ['GCDH']},
#  'SACCD3m': {'ECN': ['1.5.1.8'],
#   'ensembl_id': ['ENSG00000008311'],
#   'genes': ['AASS']},
#  'r0525': {'ECN': ['1.5.1.9'],
#   'ensembl_id': ['ENSG00000008311'],
#   'genes': ['AASS']},
#  'AASAD3m': {'ECN': ['1.2.1.31'],
#   'ensembl_id': ['ENSG00000164904'],
#   'genes': ['ALDH7A1']},
#  'R03103_MitoCore': {'ECN': ['1.2.1.31'],
#   'ensembl_id': ['ENSG00000164904'],
#   'genes': ['ALDH7A1']},
#  'r0450': {'ECN': ['2.6.1.39'],
#   'ensembl_id': ['ENSG00000109576'],
#   'genes': ['AADAT']},
#  'LYSOXc_MitoCore': {'ECN': ['1.4.3.14'],
#   'ensembl_id': ['ENSG00000109576'],
#   'genes': ['AADAT']},
#  'PPD2CSPc_MitoCore': {'ECN': ['Non-Enzymatic'],
#   'ensembl_id': ['Non-Enzymatic'],
#   'genes': ['NON-ENZYMATIC']},
#  '1PPDCRc_MitoCore': {'ECN': ['1.5.1.1', '1.5.1.21'],
#   'ensembl_id': ['Non-Enzymatic'],
#   'genes': ['NON-ENZYMATIC']},
#  '1PPDCRc_NADPH_MitoCore': {'ECN': ['1.5.1.1', '1.5.1.21'],
#   'ensembl_id': ['Non-Enzymatic'],
#   'genes': ['NON-ENZYMATIC']},
#  'LPCOXc_MitoCore': {'ECN': ['1.5.3.7'],
#   'ensembl_id': ['ENSG00000179761'],
#   'genes': ['PIPOX']},
#  'RE1254C': {'ECN': ['1.4.1.18'],
#   'ensembl_id': ['ENSG00000179761'],
#   'genes': ['PIPOX']},
#  'r0594': {'ECN': ['1.2.1.31'],
#   'ensembl_id': ['ENSG00000164904'],
#   'genes': ['ALDH7A1']},
#  '2AMADPTmB_MitoCore': {'ECN': ['N/A'],
#   'ensembl_id': ['ENSG00000183032'],
#   'genes': ['SLC25A21']},
#  '2AMADPTmC_MitoCore': {'ECN': ['N/A'],
#   'ensembl_id': ['ENSG00000183032'],
#   'genes': ['SLC25A21']},
#  'PROD2mB_MitoCore': {'ECN': ['1.5.5.2'],
#   'ensembl_id': ['ENSG00000100033'],
#   'genes': ['PRODH']},
#  'G5SADrm': {'ECN': ['Non-Enzymatic'],
#   'ensembl_id': ['Non-Enzymatic'],
#   'genes': ['NON-ENZYMATIC']},
#  'r0074': {'ECN': ['1.2.1.88'],
#   'ensembl_id': ['ENSG00000159423'],
#   'genes': ['ALDH4A1']},
#  'GLU5Km': {'ECN': ['2.7.2.11'],
#   'ensembl_id': ['ENSG00000059573'],
#   'genes': ['ALDH18A1']},
#  'G5SDym': {'ECN': ['1.2.1.41'],
#   'ensembl_id': ['ENSG00000059573'],
#   'genes': ['ALDH18A1']},
#  'P5CRm': {'ECN': ['1.5.1.2'],
#   'ensembl_id': ['ENSG00000183010'],
#   'genes': ['PYCR1']},
#  'P5CRxm': {'ECN': ['1.5.1.2'],
#   'ensembl_id': ['ENSG00000183010'],
#   'genes': ['PYCR1']},
#  'ORNTArm': {'ECN': ['2.6.1.13'],
#   'ensembl_id': ['ENSG00000065154'],
#   'genes': ['OAT']},
#  'ORNDC': {'ECN': ['4.1.1.17'],
#   'ensembl_id': ['ENSG00000115758'],
#   'genes': ['ODC1']},
#  'PTRCOX1': {'ECN': ['1.4.3.22'],
#   'ensembl_id': ['ENSG00000002726'],
#   'genes': ['AOC1']},
#  'r0464c_MitoCore': {'ECN': ['1.2.1.3'],
#   'ensembl_id': ['ENSG00000164904', 'ENSG00000143149'],
#   'genes': ['ALDH7A1', 'ALDH9A1']},
#  'ABUTD': {'ECN': ['1.2.1.3'],
#   'ensembl_id': ['ENSG00000164904', 'ENSG00000143149'],
#   'genes': ['ALDH7A1', 'ALDH9A1']},
#  'ARGDCm': {'ECN': ['4.1.1.19'],
#   'ensembl_id': ['ENSG00000142920'],
#   'genes': ['AZIN2']},
#  'AGMTm': {'ECN': ['3.5.3.11'],
#   'ensembl_id': ['ENSG00000116771'],
#   'genes': ['AGMAT']},
#  'PTRCAT1m_MitoCore': {'ECN': ['2.3.1.57'],
#   'ensembl_id': ['ENSG00000141504'],
#   'genes': ['SAT2']},
#  'APRTO2m_MitoCore': {'ECN': ['1.4.3.4'],
#   'ensembl_id': ['ENSG00000069535'],
#   'genes': ['MAOB']},
#  'NABTNOm': {'ECN': ['1.2.1.3'],
#   'ensembl_id': ['ENSG00000137124',
#    'ENSG00000072210',
#    'ENSG00000164904',
#    'ENSG00000143149'],
#   'genes': ['ALDH1B1', 'ALDH3A2', 'ALDH7A1', 'ALDH9A1']},
#  'GLUDC': {'ECN': ['4.1.1.15'],
#   'ensembl_id': ['ENSG00000136750'],
#   'genes': ['GAD2']},
#  '4ABUTtm': {'ECN': ['N/A'],
#   'ensembl_id': ['ENSG00000136750'],
#   'genes': ['GAD2']},
#  'ABTArm': {'ECN': ['2.6.1.19'],
#   'ensembl_id': ['ENSG00000183044'],
#   'genes': ['ABAT']},
#  'r0178': {'ECN': ['1.2.1.24'],
#   'ensembl_id': ['ENSG00000112294'],
#   'genes': ['ALDH5A1']},
#  'GLUDxm': {'ECN': ['1.4.1.3'],
#   'ensembl_id': ['ENSG00000148672', 'ENSG00000182890'],
#   'genes': ['GLUD1', 'GLUD2']},
#  'GLUDym': {'ECN': ['1.4.1.3'],
#   'ensembl_id': ['ENSG00000148672', 'ENSG00000182890'],
#   'genes': ['GLUD1', 'GLUD2']},
#  'GLUDxi': {'ECN': ['1.4.1.3'],
#   'ensembl_id': ['ENSG00000148672'],
#   'genes': ['GLUD1']},
#  'GLUDy': {'ECN': ['1.4.1.3'],
#   'ensembl_id': ['ENSG00000148672'],
#   'genes': ['GLUD1']},
#  'GLNS': {'ECN': ['6.3.1.2'],
#   'ensembl_id': ['ENSG00000135821'],
#   'genes': ['GLUL']},
#  'GLUNm': {'ECN': ['3.5.1.2'],
#   'ensembl_id': ['ENSG00000115419', 'ENSG00000135423'],
#   'genes': ['GLS', 'GLS2']},
#  'GLUN_MitoCore': {'ECN': ['3.5.1.2'],
#   'ensembl_id': ['ENSG00000115419', 'ENSG00000084774'],
#   'genes': ['GLS', 'CAD']},
#  'PGCD': {'ECN': ['1.1.1.95'],
#   'ensembl_id': ['ENSG00000092621'],
#   'genes': ['PHGDH']},
#  'PSERT': {'ECN': ['2.6.1.52'],
#   'ensembl_id': ['ENSG00000135069'],
#   'genes': ['PSAT1']},
#  'PSP_L': {'ECN': ['3.1.3.3'],
#   'ensembl_id': ['ENSG00000146733'],
#   'genes': ['PSPH']},
#  'GHMT2r': {'ECN': ['2.1.2.1'],
#   'ensembl_id': ['ENSG00000176974'],
#   'genes': ['SHMT1']},
#  'FOLR2': {'ECN': ['1.5.1.3'],
#   'ensembl_id': ['ENSG00000228716'],
#   'genes': ['DHFR']},
#  'DHFR': {'ECN': ['1.5.1.3'],
#   'ensembl_id': ['ENSG00000228716'],
#   'genes': ['DHFR']},
#  'MTHFD': {'ECN': ['1.5.1.5'],
#   'ensembl_id': ['ENSG00000100714'],
#   'genes': ['MTHFD1']},
#  'MTHFC': {'ECN': ['3.5.4.9'],
#   'ensembl_id': ['ENSG00000100714', 'ENSG00000163738'],
#   'genes': ['MTHFD1', 'MTHFD2L']},
#  'FTCD': {'ECN': ['4.3.1.4'],
#   'ensembl_id': ['ENSG00000160282'],
#   'genes': ['FTCD']},
#  'FTHFL': {'ECN': ['6.3.4.3'],
#   'ensembl_id': ['ENSG00000100714'],
#   'genes': ['MTHFD1']},
#  'FTHFDH': {'ECN': ['1.5.1.6'],
#   'ensembl_id': ['ENSG00000144908'],
#   'genes': ['ALDH1L1']},
#  'r0060': {'ECN': ['4.3.1.17', '4.3.1.19'],
#   'ensembl_id': ['ENSG00000135094', 'ENSG00000167720', 'ENSG00000139410'],
#   'genes': ['SDS', 'SRR', 'SDSL']},
#  'GHMT2rm': {'ECN': ['2.1.2.1'],
#   'ensembl_id': ['ENSG00000182199'],
#   'genes': ['SHMT2']},
#  'GCCam': {'ECN': ['1.4.4.2'],
#   'ensembl_id': ['ENSG00000178445'],
#   'genes': ['GLDC']},
#  'GCCbim': {'ECN': ['2.1.2.10'],
#   'ensembl_id': ['ENSG00000145020'],
#   'genes': ['AMT']},
#  'GCCcm': {'ECN': ['1.8.1.4'],
#   'ensembl_id': ['ENSG00000091140'],
#   'genes': ['DLD']},
#  'r0514': {'ECN': ['1.5.1.3'],
#   'ensembl_id': ['ENSG00000178700'],
#   'genes': ['DHFRL1']},
#  'r0226': {'ECN': ['1.5.1.3'],
#   'ensembl_id': ['ENSG00000178700'],
#   'genes': ['DHFRL1']},
#  'MTHFDm': {'ECN': ['1.5.1.5'],
#   'ensembl_id': ['ENSG00000163738'],
#   'genes': ['MTHFD2L']},
#  'MTHFD2m': {'ECN': ['1.5.1.15'],
#   'ensembl_id': ['ENSG00000163738', 'ENSG00000065911'],
#   'genes': ['MTHFD2L', 'MTHFD2']},
#  'MTHFCm': {'ECN': ['3.5.4.9'],
#   'ensembl_id': ['ENSG00000163738', 'ENSG00000065911'],
#   'genes': ['MTHFD2L', 'MTHFD2']},
#  'FTHFLm': {'ECN': ['6.3.4.3'],
#   'ensembl_id': ['ENSG00000120254'],
#   'genes': ['MTHFD1L']},
#  'FTHFDHm_MitoCore': {'ECN': ['1.5.1.6'],
#   'ensembl_id': ['ENSG00000136010'],
#   'genes': ['ALDH1L2']},
#  'GLYATm': {'ECN': ['2.3.1.29'],
#   'ensembl_id': ['ENSG00000100116'],
#   'genes': ['GCAT']},
#  'AOBUTDsm': {'ECN': ['Non-enzymatic'],
#   'ensembl_id': ['Non-enzymatic'],
#   'genes': ['NON-ENZYMATIC']},
#  'AACTOORm_MitoCore': {'ECN': ['1.4.3.4'],
#   'ensembl_id': ['ENSG00000069535'],
#   'genes': ['MAOB']},
#  'LGTHLm_MitoCore': {'ECN': ['4.4.1.5'],
#   'ensembl_id': ['ENSG00000124767'],
#   'genes': ['GLO1']},
#  'GLYOXm': {'ECN': ['3.1.2.6'],
#   'ensembl_id': ['ENSG00000063854'],
#   'genes': ['HAGH']},
#  'LDH_Dm_MitoCore': {'ECN': ['1.1.1.28'],
#   'ensembl_id': ['ENSG00000166816'],
#   'genes': ['LDHD']},
#  'CBPSam': {'ECN': ['6.3.4.16'],
#   'ensembl_id': ['ENSG00000021826'],
#   'genes': ['CPS1']},
#  'OCBTm': {'ECN': ['2.1.3.3'],
#   'ensembl_id': ['ENSG00000036473'],
#   'genes': ['OTC']},
#  'NOS1': {'ECN': ['1.14.13.39'],
#   'ensembl_id': ['ENSG00000007171'],
#   'genes': ['NOS2']},
#  'NOS2': {'ECN': ['1.14.13.39'],
#   'ensembl_id': ['ENSG00000007171'],
#   'genes': ['NOS2']},
#  'r0129': {'ECN': ['3.4.19.13'],
#   'ensembl_id': ['ENSG00000167741', 'ENSG00000131067'],
#   'genes': ['GGT6', 'GGT7']},
#  'AMPTASECG': {'ECN': ['3.4.11.2'],
#   'ensembl_id': ['ENSG00000166825'],
#   'genes': ['ANPEP']},
#  'GLUCYS': {'ECN': ['6.3.2.2'],
#   'ensembl_id': ['ENSG00000001084'],
#   'genes': ['GCLC']},
#  'GTHS': {'ECN': ['6.3.2.3'],
#   'ensembl_id': ['ENSG00000100983'],
#   'genes': ['GSS']},
#  'r0399': {'ECN': ['1.14.16.1'],
#   'ensembl_id': ['ENSG00000171759'],
#   'genes': ['PAH']},
#  'DHPR': {'ECN': ['1.5.1.34'],
#   'ensembl_id': ['ENSG00000151552'],
#   'genes': ['QDPR']},
#  'TYRTA': {'ECN': ['2.6.1.1', '2.6.1.5'],
#   'ensembl_id': ['ENSG00000120053'],
#   'genes': ['GOT1']},
#  'TYRTB_MitoCore': {'ECN': ['1.4.3.2'],
#   'ensembl_id': ['ENSG00000104951'],
#   'genes': ['IL4I1']},
#  '34HPPOR': {'ECN': ['1.13.11.27'],
#   'ensembl_id': ['ENSG00000158104'],
#   'genes': ['HPD']},
#  'HGNTOR': {'ECN': ['1.13.11.5'],
#   'ensembl_id': ['ENSG00000113924'],
#   'genes': ['HGD']},
#  'MACACI': {'ECN': ['5.2.1.2'],
#   'ensembl_id': ['ENSG00000100577'],
#   'genes': ['GSTZ1']},
#  'FUMAC': {'ECN': ['3.7.1.2'],
#   'ensembl_id': ['ENSG00000103876'],
#   'genes': ['FAH']},
#  'ASNS1': {'ECN': ['6.3.5.4'],
#   'ensembl_id': ['ENSG00000070669'],
#   'genes': ['ASNS']},
#  'r0127': {'ECN': ['3.5.1.1'],
#   'ensembl_id': ['ENSG00000166183'],
#   'genes': ['ASPG']},
#  'HISD': {'ECN': ['4.3.1.3'],
#   'ensembl_id': ['ENSG00000084110'],
#   'genes': ['HAL']},
#  'URCN': {'ECN': ['4.2.1.49'],
#   'ensembl_id': ['ENSG00000159650'],
#   'genes': ['UROC1']},
#  'IZPN': {'ECN': ['3.5.2.7'],
#   'ensembl_id': ['ENSG00000139344'],
#   'genes': ['AMDHD1']},
#  'GluForTx': {'ECN': ['2.1.2.5'],
#   'ensembl_id': ['ENSG00000160282'],
#   'genes': ['FTCD']},
#  'APAT2rm': {'ECN': ['2.6.1.19'],
#   'ensembl_id': ['ENSG00000183044'],
#   'genes': ['ABAT']},
#  'MMSAD3m': {'ECN': ['1.2.1.18'],
#   'ensembl_id': ['ENSG00000119711'],
#   'genes': ['ALDH6A1']},
#  'MMSAD3m2_MitoCore': {'ECN': ['1.2.1.18'],
#   'ensembl_id': ['ENSG00000119711'],
#   'genes': ['ALDH6A1']},
#  'ASP1DC': {'ECN': ['4.1.1.11'],
#   'ensembl_id': ['ENSG00000144644'],
#   'genes': ['GADL1']},
#  'CKc': {'ECN': ['2.7.3.2'],
#   'ensembl_id': ['ENSG00000166165', 'ENSG00000104879'],
#   'genes': ['CKB', 'CKM']},
#  'CK': {'ECN': ['2.7.3.2'],
#   'ensembl_id': ['ENSG00000131730'],
#   'genes': ['CKMT2']},
#  'ACOAHi': {'ECN': ['3.1.2.1'],
#   'ensembl_id': ['ENSG00000172497'],
#   'genes': ['ACOT12']},
#  'ALCD2yf': {'ECN': ['1.1.1.2'],
#   'ensembl_id': ['ENSG00000117448'],
#   'genes': ['AKR1A1']},
#  'ALCD2if': {'ECN': ['1.1.1.1'],
#   'ensembl_id': ['ENSG00000248144', 'ENSG00000197894'],
#   'genes': ['ADH1C', 'ADH5']},
#  'ACALDtm': {'ECN': ['N/A'], 'ensembl_id': ['N/A'], 'genes': ['N/A']},
#  'ALDD2xm': {'ECN': ['1.2.1.3'],
#   'ensembl_id': ['ENSG00000137124',
#    'ENSG00000072210',
#    'ENSG00000164904',
#    'ENSG00000143149'],
#   'genes': ['ALDH1B1', 'ALDH3A2', 'ALDH7A1', 'ALDH9A1']},
#  'ALDD2x': {'ECN': ['1.2.1.3'],
#   'ensembl_id': ['ENSG00000164904', 'ENSG00000143149'],
#   'genes': ['ALDH7A1', 'ALDH9A1']},
#  'ACSm': {'ECN': ['6.2.1.1'],
#   'ensembl_id': ['ENSG00000154930'],
#   'genes': ['ACSS1']},
#  'ACS': {'ECN': ['6.2.1.1'],
#   'ensembl_id': ['ENSG00000131069'],
#   'genes': ['ACSS2']},
#  'ADSL1': {'ECN': ['4.3.2.2'],
#   'ensembl_id': ['ENSG00000239900'],
#   'genes': ['ADSL']},
#  'ADSS': {'ECN': ['6.3.4.4'],
#   'ensembl_id': ['ENSG00000035687', 'ENSG00000185100'],
#   'genes': ['ADSS', 'ADSSL1']},
#  'AMPD1': {'ECN': ['3.5.4.6'],
#   'ensembl_id': ['ENSG00000116748'],
#   'genes': ['AMPD1']},
#  'ARGN': {'ECN': ['3.5.3.1'],
#   'ensembl_id': ['ENSG00000118520'],
#   'genes': ['ARG1']},
#  'ARGSL': {'ECN': ['4.3.2.1'],
#   'ensembl_id': ['ENSG00000126522'],
#   'genes': ['ASL']},
#  'ARGSS': {'ECN': ['6.3.4.5'],
#   'ensembl_id': ['ENSG00000130707'],
#   'genes': ['ASS1']},
#  'ARGNm': {'ECN': ['3.5.3.1'],
#   'ensembl_id': ['ENSG00000081181'],
#   'genes': ['ARG2']},
#  'ALASm': {'ECN': ['2.3.1.37'],
#   'ensembl_id': ['ENSG00000023330'],
#   'genes': ['ALAS1']},
#  '5AOPtm': {'ECN': ['N/A'],
#   'ensembl_id': ['ENSG00000023330'],
#   'genes': ['ALAS1']},
#  'PPBNGS': {'ECN': ['4.2.1.24'],
#   'ensembl_id': ['ENSG00000148218'],
#   'genes': ['ALAD']},
#  'HMBS': {'ECN': ['2.5.1.61'],
#   'ensembl_id': ['ENSG00000256269'],
#   'genes': ['HMBS']},
#  'UPP3S': {'ECN': ['4.2.1.75'],
#   'ensembl_id': ['ENSG00000188690'],
#   'genes': ['UROS']},
#  'UPPDC1': {'ECN': ['4.1.1.37'],
#   'ensembl_id': ['ENSG00000126088'],
#   'genes': ['UROD']},
#  'CPPPGO': {'ECN': ['1.3.3.3'],
#   'ensembl_id': ['ENSG00000080819'],
#   'genes': ['CPOX']},
#  'PPPGOmB_MitoCore': {'ECN': ['1.3.3.4'],
#   'ensembl_id': ['ENSG00000143224'],
#   'genes': ['PPOX']},
#  'FCLTm': {'ECN': ['4.99.1.1'],
#   'ensembl_id': ['ENSG00000066926'],
#   'genes': ['FECH']},
#  'PHEMEtm': {'ECN': ['N/A'],
#   'ensembl_id': ['ENSG00000066926'],
#   'genes': ['FECH']},
#  'HOXG': {'ECN': ['1.14.99.3'],
#   'ensembl_id': ['ENSG00000100292', 'ENSG00000103415'],
#   'genes': ['HMOX1', 'HMOX2']},
#  'BILIRED': {'ECN': ['1.3.1.24'],
#   'ensembl_id': ['ENSG00000090013'],
#   'genes': ['BLVRB']},
#  'BILIRED2_MitoCore': {'ECN': ['1.3.1.24'],
#   'ensembl_id': ['ENSG00000106605'],
#   'genes': ['BLVRA']},
#  'PCHOLPm_hs': {'ECN': ['3.1.4.4'],
#   'ensembl_id': ['ENSG00000105223'],
#   'genes': ['PLD3']},
#  'GLYK': {'ECN': ['2.7.1.30'],
#   'ensembl_id': ['ENSG00000198814'],
#   'genes': ['GK']},
#  'GLYC3Ptm': {'ECN': ['N/A'],
#   'ensembl_id': ['ENSG00000198814'],
#   'genes': ['GK']},
#  'GPAMm_hsB_MitoCore': {'ECN': ['2.3.1.15'],
#   'ensembl_id': ['ENSG00000186281'],
#   'genes': ['GPAT2']},
#  'AGPAT1B_MitoCore': {'ECN': ['2.3.1.51'],
#   'ensembl_id': ['ENSG00000155189'],
#   'genes': ['AGPAT5']},
#  'CDSm': {'ECN': ['2.7.7.41'],
#   'ensembl_id': ['ENSG00000144559'],
#   'genes': ['TAMM41']},
#  'PGPPTm': {'ECN': ['2.7.8.5'],
#   'ensembl_id': ['ENSG00000087157'],
#   'genes': ['PGS1']},
#  'PGPP_hsm_MitoCore': {'ECN': ['3.1.3.27'],
#   'ensembl_id': ['ENSG00000110536'],
#   'genes': ['PTPMT1']},
#  'CLS_hsm_MitoCore': {'ECN': ['2.7.8.41'],
#   'ensembl_id': ['ENSG00000088766'],
#   'genes': ['CRLS1']},
#  'CLPN_MitoCore': {'ECN': ['2.7.8.-'],
#   'ensembl_id': ['ENSG00000088766'],
#   'genes': ['CRLS1']},
#  'CYTK1m': {'ECN': ['2.7.4.14'],
#   'ensembl_id': ['ENSG00000134326'],
#   'genes': ['CMPK2']},
#  'NDPK3m': {'ECN': ['2.7.4.6'],
#   'ensembl_id': ['ENSG00000103202'],
#   'genes': ['NME4']},
#  'SPODMm': {'ECN': ['1.15.1.1'],
#   'ensembl_id': ['ENSG00000142168', 'ENSG00000112096'],
#   'genes': ['SOD1', 'SOD2']},
#  'GTHP': {'ECN': ['1.11.1.9'],
#   'ensembl_id': ['ENSG00000176153'],
#   'genes': ['GPX2']},
#  'GTHPm': {'ECN': ['1.11.1.9'],
#   'ensembl_id': ['ENSG00000233276'],
#   'genes': ['GPX1']},
#  'GTHO': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000104687'],
#   'genes': ['GSR']},
#  'GTHOm': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000104687'],
#   'genes': ['GSR']},
#  'CITtamB': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000100075'],
#   'genes': ['SLC25A1']},
#  'r0913': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000100075'],
#   'genes': ['SLC25A1']},
#  'CITtbm': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000100075'],
#   'genes': ['SLC25A1']},
#  'r0917': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000100075'],
#   'genes': ['SLC25A1']},
#  'r0917b_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000100075'],
#   'genes': ['SLC25A1']},
#  'PIt2mB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000075415'],
#   'genes': ['SLC25A3']},
#  'ATPtmB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000151729', 'ENSG00000005022', 'ENSG00000169100'],
#   'genes': ['SLC25A4', 'SLC25A5', 'SLC25A6']},
#  'HtmB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000175567', 'ENSG00000175564'],
#   'genes': ['UCP2']},
#  'MALtm': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000183048'],
#   'genes': ['SLC25A10']},
#  'MALSO3tm': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000183048'],
#   'genes': ['SLC25A10']},
#  'MALTSULtm': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000183048'],
#   'genes': ['SLC25A10']},
#  'MALSO4tm': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000183048'],
#   'genes': ['SLC25A10']},
#  'SUCCt2m': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000183048'],
#   'genes': ['SLC25A10']},
#  'r0830': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000183048'],
#   'genes': ['SLC25A10']},
#  'r0830B_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000183048'],
#   'genes': ['SLC25A10']},
#  'r0829': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000183048'],
#   'genes': ['SLC25A10']},
#  'SUCCt3m_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000183048'],
#   'genes': ['SLC25A10']},
#  'COAtmB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000181035'],
#   'genes': ['SLC25A42']},
#  'COAtmC_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000181035'],
#   'genes': ['SLC25A42']},
#  'GLUt2mB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000182902'],
#   'genes': ['SLC25A18']},
#  'ORNt4mB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000102743'],
#   'genes': ['SLC25A15']},
#  'r2398B_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000102743'],
#   'genes': ['SLC25A15']},
#  'r2402B_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000102743'],
#   'genes': ['SLC25A15']},
#  'LYStmB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000197119'],
#   'genes': ['SLC25A29']},
#  'ORNt3mB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000197119'],
#   'genes': ['SLC25A29']},
#  'ARGtmB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000197119'],
#   'genes': ['SLC25A29']},
#  'r1427': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000197119'],
#   'genes': ['SLC25A29']},
#  'PYRt2m': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000060762', 'ENSG00000143158'],
#   'genes': ['MPC1', 'MPC2']},
#  'ACACt2mB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000060762', 'ENSG00000143158'],
#   'genes': ['MPC1', 'MPC2']},
#  'FE2tm': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'ASNtm': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'r1437': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'GLNtm': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'PROtm': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'r1078': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'r1436': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'r1455': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'TRPtm_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'GLYtm': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'ILEt5m': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'LEUt5m': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'VALt5m': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'r1434': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'r1435': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'r1440': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'BALAtmr': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'UREAtm': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'FUMtmB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'BHBtmB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'PPAtmB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'BUTt2mB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
#   'genes': ['SLC25A37', 'SLC25A28']},
#  'FORt2mB_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000147454', 'ENSG00000155287'],
# ...
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'ICITt_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'UREAt': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'r1512': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'ARGSUCt_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'MAL_Lte': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'OAAt_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'AKGt_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'MERCPLACt_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'r0899': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'FE2t': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'H2Ot': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'Hct_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'Hmt_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'SO3t_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'TSULt_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'r0940': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'CYANt': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'TCYNTt': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'r1423': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'FORt_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'FOLt_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'NADHt_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'NADt_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'NADHtm_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'NADtm_MitoCore': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'COt': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'NOt': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'PCHOLHSTDe': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'PSt3': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']},
#  'PEt': {'ECN': ['1.8.1.7'],
#   'ensembl_id': ['ENSG00000124406',
#    'ENSG00000143515',
#    'ENSG00000081923',
#    'ENSG00000104043',
#    'ENSG00000054793',
#    'ENSG00000166377',
#    'ENSG00000206190',
#    'ENSG00000145246',
#    'ENSG00000068650',
#    'ENSG00000058063',
#    'ENSG00000101974',
#    'ENSG00000112697',
#    'ENSG00000182107'],
#   'genes': ['ATP8A1',
#    'ATP8B1',
#    'ATP8B2',
#    'ATP8B4',
#    'ATP9A',
#    'ATP9B',
#    'ATP10A',
#    'ATP10D',
#    'ATP11A',
#    'ATP11B',
#    'ATP11C',
#    'TMEM30A',
#    'TMEM30B']}}

# %%
dict_synonyms
# Out:
# {'ACOX2': {'Synonyms': ['ACOX2,',
#    'BCOX,',
#    'BRCACOX,',
#    'BRCOX,',
#    'CBAS6,',
#    'THCCOX'],
#   'ECN': '1.17.99.3',
#   'ensembl_id': 'ENSG00000168306'},
#  'ACSS2': {'Synonyms': ['ACSS2,',
#    'ACAS2,',
#    'ACECS,',
#    'ACS,',
#    'ACSA,',
#    'ACECS1,',
#    'DJ1161H23.1'],
#   'ECN': '6.2.1.1',
#   'ensembl_id': 'ENSG00000131069'},
#  'ADAMTS2': {'Synonyms': ['ADAMTS2,',
#    'ADAM-TS2,',
#    'ADAMTS-2,',
#    'ADAMTS-3,',
#    'EDSDERMS,',
#    'NPI,',
#    'PC_I-NP,',
#    'PCI-NP,',
#    'PCINP,',
#    'PCPNI,',
#    'PNPI'],
#   'ECN': '3.4.24.14',
#   'ensembl_id': 'ENSG00000087116'},
#  'AEBP1': {'Synonyms': ['AEBP1,', 'ACLP'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000106624'},
#  'AKR1B10': {'Synonyms': ['AKR1B10,',
#    'AKR1B11,',
#    'AKR1B12,',
#    'ALDRLN,',
#    'ARL-1,',
#    'ARL1,',
#    'HIS,',
#    'HSI'],
#   'ECN': '1.1.1.21',
#   'ensembl_id': 'ENSG00000198074'},
#  'ALOX5': {'Synonyms': ['ALOX5,', '5-LO,', '5-LOX,', '5LPG,', 'LOG5'],
#   'ECN': '1.13.11.34',
#   'ensembl_id': 'ENSG00000012779'},
#  'ANKRD1': {'Synonyms': ['ANKRD13C,', 'DJ677H15.3'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000118454'},
#  'ANXA3': {'Synonyms': ['ANXA3,', 'ANX3'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000138772'},
#  'ARPP21': {'Synonyms': ['ARPP21,', 'ARPP-21,', 'R3HDM3,', 'RCS,', 'TARPP'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000172995'},
#  'ATF4': {'Synonyms': ['ATF4,', 'CREB-2,', 'CREB2,', 'TAXREB67,', 'TXREB'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000128272'},
#  'B3GNT5': {'Synonyms': ['B3GNT5,', 'B3GN-T5,', 'BETA3GN-T5'],
#   'ECN': '2.4.1.206',
#   'ensembl_id': 'ENSG00000176597'},
#  'BEX4': {'Synonyms': ['BEX4,', 'BEXL1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000102409'},
#  'Bglap2': {'Synonyms': ['BGLAP2'], 'ECN': 0, 'ensembl_id': 0},
#  'BGN': {'Synonyms': ['BGN'], 'ECN': 0, 'ensembl_id': 0},
#  'BIN1': {'Synonyms': ['CABIN1,', 'CAIN,', 'KB-318B8.7,', 'PPP3IN'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000099991'},
#  'BMP4': {'Synonyms': ['BMP4,',
#    'BMP2B,',
#    'BMP2B1,',
#    'MCOPS6,',
#    'OFC11,',
#    'ZYME'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000125378'},
#  'C1orf93': {'Synonyms': ['PRXL2B,', 'C1ORF93,', 'FAM213B'],
#   'ECN': '1.11.1.20',
#   'ensembl_id': 'ENSG00000157870'},
#  'C2': {'Synonyms': ['C2'], 'ECN': 0, 'ensembl_id': 0},
#  'C5orf13': {'Synonyms': ['NREP,',
#    'C5ORF13,',
#    'D4S114,',
#    'P311,',
#    'PRO1873,',
#    'PTZ17,',
#    'SEZ17'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000134986'},
#  'CAV1': {'Synonyms': ['CACNA1C,',
#    'CACH2,',
#    'CACN2,',
#    'CACNA1C-IT2,',
#    'CACNL1A1,',
#    'CCHL1A1,',
#    'CAV1.2,',
#    'LQT8,',
#    'NEDHLSS,',
#    'TS,',
#    'TS._LQT8'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000151067'},
#  'CCL7': {'Synonyms': ['CCL7,',
#    'FIC,',
#    'MARC,',
#    'MCP-3,',
#    'MCP3,',
#    'NC28,',
#    'SCYA6,',
#    'SCYA7'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000108688'},
#  'CDSN': {'Synonyms': ['CDSN,', 'HTSS,', 'HTSS1,', 'HYPT2,', 'PSS,', 'PSS1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000204539'},
#  'CDV3': {'Synonyms': ['CDV3,', 'H41'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000091527'},
#  'CENPA': {'Synonyms': ['CENPA,', 'CENP-A,', 'CENH3'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000115163'},
#  'CHAC1': {'Synonyms': ['CHAC1'],
#   'ECN': '4.3.2.7',
#   'ensembl_id': 'ENSG00000128965'},
#  'CHCHD10': {'Synonyms': ['CHCHD10,',
#    'C22ORF16,',
#    'FTDALS2,',
#    'IMMD,',
#    'MIX17A,',
#    'N27C7-4,',
#    'SMAJ'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000250479'},
#  'CHI3L1': {'Synonyms': ['CHI3L1,',
#    'ASRT7,',
#    'CGP-39,',
#    'GP-39,',
#    'GP39,',
#    'HC-GP39,',
#    'HCGP-3P,',
#    'YK-40,',
#    'YKL-40,',
#    'YKL40,',
#    'YYL-40,',
#    'HCGP-39'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000133048'},
#  'CHRNA1': {'Synonyms': ['CHRNA1,',
#    'ACHRA,',
#    'ACHRD,',
#    'CHRNA,',
#    'CMS1A,',
#    'CMS1B,',
#    'CMS2A,',
#    'FCCMS,',
#    'SCCMS'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000138435'},
#  'CHRNG': {'Synonyms': ['CHRNG,', 'ACHRG'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000196811'},
#  'CKB': {'Synonyms': ['CKB'], 'ECN': 0, 'ensembl_id': 0},
#  'COL1A1': {'Synonyms': ['COL1A1,',
#    'CAFYD,',
#    'EDSARTH1,',
#    'EDSC,',
#    'OI1,',
#    'OI2,',
#    'OI3,',
#    'OI4'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000108821'},
#  'COL3A1': {'Synonyms': ['COL3A1,', 'EDS4A,', 'EDSVASC,', 'PMGEDSV'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000168542'},
#  'COL5A1': {'Synonyms': ['COL5A1,', 'EDSC,', 'EDSCL1,', 'FMDMF'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000130635'},
#  'COL6A1': {'Synonyms': ['COL6A1,', 'BTHLM1,', 'OPLL,', 'UCHMD1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000142156'},
#  'COL6A2': {'Synonyms': ['COL6A2,', 'BTHLM1,', 'PP3610,', 'UCMD1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000142173'},
#  'COX6A2': {'Synonyms': ['COX6A2,',
#    'COX6AH,',
#    'COXVIAH,',
#    'COXVIA-M,',
#    'MC4DN18'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000156885'},
#  'Cox8b': {'Synonyms': ['COX8B'], 'ECN': 0, 'ensembl_id': 0},
#  'CPXM1': {'Synonyms': ['CPXM1,', 'CPX1,', 'CPXM'],
#   'ECN': '3.4.17.-',
#   'ensembl_id': 'ENSG00000088882'},
#  'CRCT1': {'Synonyms': ['CRCT1,', 'C1ORF42,', 'NICE-1,', 'NICE1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000169509'},
#  'CREB3': {'Synonyms': ['CREB3,', 'LUMAN,', 'LZIP,', 'SLZIP'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000107175'},
#  'CRTAP': {'Synonyms': ['CRTAP,', 'CASP,', 'LEPREL3,', 'OI7,', 'P3H5'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000170275'},
#  '2600001J17RIK': {'Synonyms': ['2600001J17RIK'], 'ECN': 0, 'ensembl_id': 0},
#  '3110007F17RIK': {'Synonyms': ['3110007F17RIK'], 'ECN': 0, 'ensembl_id': 0},
#  '5031425E22RIK': {'Synonyms': ['5031425E22RIK'], 'ECN': 0, 'ensembl_id': 0},
#  'A730054J21RIK': {'Synonyms': ['A730054J21RIK'], 'ECN': 0, 'ensembl_id': 0},
#  'A930016D02RIK': {'Synonyms': ['A930016D02RIK'], 'ECN': 0, 'ensembl_id': 0},
#  'AMOTL1': {'Synonyms': ['AMOTL1,', 'JEAP'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000166025'},
#  'ARHGEF11': {'Synonyms': ['ARHGEF11,', 'GTRAP48,', 'PDZ-RHOGEF'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000132694'},
#  'AVPR1A': {'Synonyms': ['AVPR1A,', 'AVPR_V1A,', 'AVPR1,', 'V1AR'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000166148'},
#  'AW212394': {'Synonyms': ['AW212394'], 'ECN': 0, 'ensembl_id': 0},
#  'BRD2': {'Synonyms': ['BRD2,',
#    'BRD2-IT1,',
#    'D6S113E,',
#    'FSH,',
#    'FSHRG1,',
#    'FSRG1,',
#    'NAT,',
#    'O27.1.1,',
#    'RING3,',
#    'RNF3'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000204256'},
#  'CD200': {'Synonyms': ['CD200R1,', 'CD200R,', 'HCRTR2,', 'MOX2R,', 'OX2R'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000163606'},
#  'CD40': {'Synonyms': ['CD40'], 'ECN': 0, 'ensembl_id': 0},
#  'COL6A3': {'Synonyms': ['COL6A3,', 'BTHLM1,', 'DYT27,', 'UCMD1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000163359'},
#  'CTGF': {'Synonyms': ['CCN2,', 'CTGF,', 'HCS24,', 'IGFBP8,', 'NOV2'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000118523'},
#  'EFS': {'Synonyms': ['EFS'], 'ECN': 0, 'ensembl_id': 0},
#  'FHL1': {'Synonyms': ['CFHR1,',
#    'CFHL,',
#    'CFHL1,',
#    'CFHL1P,',
#    'CFHR1P,',
#    'FHL-1,',
#    'FHR-1,',
#    'FHR1,',
#    'H36,',
#    'H36-1,',
#    'H36-2,',
#    'HFL1,',
#    'HFL2'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000244414'},
#  'GM1012': {'Synonyms': ['GM1012'], 'ECN': 0, 'ensembl_id': 0},
#  'HIST1H1C': {'Synonyms': ['H1-2,',
#    'H1.2,',
#    'H1C,',
#    'H1F2,',
#    'H1S-1,',
#    'HIST1H1C'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000187837'},
#  'HOXB7': {'Synonyms': ['HOXB7,', 'HHO.C1,', 'HOX2,', 'HOX2C,', 'HOX-2.3'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000260027'},
#  'HTRA1': {'Synonyms': ['HTRA1,',
#    'ARMD7,',
#    'CADASIL2,',
#    'CARASIL,',
#    'HTRA,',
#    'L56,',
#    'ORF480,',
#    'PRSS11'],
#   'ECN': '3.4.21.-',
#   'ensembl_id': 'ENSG00000166033'},
#  'IGF2BP1': {'Synonyms': ['IGF2BP1,',
#    'CRD-BP,',
#    'CRDBP,',
#    'IMP-1,',
#    'IMP1,',
#    'VICKZ1,',
#    'ZBP1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000159217'},
#  'IGFBP2': {'Synonyms': ['IGFBP2,', 'IBP2,', 'IGF-BP53'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000115457'},
#  'KLRA18': {'Synonyms': ['KLRA18'], 'ECN': 0, 'ensembl_id': 0},
#  'LOC195357': {'Synonyms': ['LOC195357'], 'ECN': 0, 'ensembl_id': 0},
#  'LOC228790': {'Synonyms': ['LOC228790'], 'ECN': 0, 'ensembl_id': 0},
#  'LOC268393': {'Synonyms': ['LOC268393'], 'ECN': 0, 'ensembl_id': 0},
#  'LOC381283': {'Synonyms': ['LOC381283'], 'ECN': 0, 'ensembl_id': 0},
#  'LRRC57': {'Synonyms': ['LRRC57'], 'ECN': 0, 'ensembl_id': 'ENSG00000180979'},
#  'MBC2': {'Synonyms': ['ESYT1,', 'FAM62A,', 'MBC2'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000139641'},
#  'NCAPH2': {'Synonyms': ['NCAPH2,', 'CAPH2'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000025770'},
#  'NKIRAS2': {'Synonyms': ['NKIRAS2,', 'KBRAS2,', 'KAPPAB-RAS2'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000168256'},
#  'PAPSS1': {'Synonyms': ['PAPSS1'], 'ECN': 0, 'ensembl_id': 0},
#  'PDCD1LG1': {'Synonyms': ['CD274,',
#    'B7-H,',
#    'B7H1,',
#    'PD-L1,',
#    'PDCD1L1,',
#    'PDCD1LG1,',
#    'PDL1,',
#    'HPD-L1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000120217'},
#  'PLF': {'Synonyms': ['PLF'], 'ECN': 0, 'ensembl_id': 0},
#  'PLF2': {'Synonyms': ['PLF2'], 'ECN': 0, 'ensembl_id': 0},
#  'PNPLA2': {'Synonyms': ['PNPLA2,',
#    '1110001C14RIK,',
#    'ATGL,',
#    'FP17548,',
#    'PEDF-R,',
#    'TTS-2.2,',
#    'TTS2,',
#    'IPLA2ZETA'],
#   'ECN': '3.1.1.3',
#   'ensembl_id': 'ENSG00000177666'},
#  'PRSS19': {'Synonyms': ['KLK8,', 'HNP,', 'NP,', 'NRPN,', 'PRSS19,', 'TADG14'],
#   'ECN': '3.4.21.118',
#   'ensembl_id': 'ENSG00000129455'},
#  'RFTN2': {'Synonyms': ['RFTN2,', 'C2ORF11,', 'RAFTLIN-2'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000162944'},
#  'SCL000959.1_2': {'Synonyms': ['SCL000959.1_2'], 'ECN': 0, 'ensembl_id': 0},
#  'SCT': {'Synonyms': ['SCT'], 'ECN': 0, 'ensembl_id': 0},
#  'SLC2A12': {'Synonyms': ['SLC2A12,', 'GLUT12,', 'GLUT8'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000146411'},
#  'STEAP2': {'Synonyms': ['STEAP2,',
#    'IPCA1,',
#    'PCANAP1,',
#    'PUMPCN,',
#    'STAMP1,',
#    'STMP'],
#   'ECN': '1.16.1.-',
#   'ensembl_id': 'ENSG00000157214'},
#  'TIMP1': {'Synonyms': ['TIMP1,',
#    'CLGI,',
#    'EPA,',
#    'EPO,',
#    'HCI,',
#    'TIMP,',
#    'TIMP-1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000102265'},
#  'TOMM22': {'Synonyms': ['TOMM22,', '1C9-2,', 'MST065,', 'MSTP065,', 'TOM22'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000100216'},
#  'TSRC1': {'Synonyms': ['ADAMTSL4,', 'ADAMTSL-4,', 'ECTOL2,', 'TSRC1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000143382'},
#  'UBE1L': {'Synonyms': ['UBA6,', 'E1-L2,', 'MOP-4,', 'UBE1L2'],
#   'ECN': '6.2.1.45',
#   'ensembl_id': 'ENSG00000033178'},
#  'WDFY1': {'Synonyms': ['WDFY1,', 'FENS-1,', 'FENS1,', 'WDF1,', 'ZFYVE17'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000085449'},
#  'A4GALT': {'Synonyms': ['B4GALT5,',
#    'B4GAL-T5,',
#    'BETA4-GALT-IV,',
#    'BETA4GAL-T5,',
#    'BETA4GALT-V,',
#    'GT-V'],
#   'ECN': '2.4.1.274 2.4.1.-',
#   'ensembl_id': 'ENSG00000158470'},
#  'ACAA1': {'Synonyms': ['ACAA1,', 'ACAA,', 'LNC-MYD88,', 'PTHIO,', 'THIO'],
#   'ECN': '2.3.1.16',
#   'ensembl_id': 'ENSG00000060971'},
#  'Acaalb': {'Synonyms': ['ACAALB'], 'ECN': 0, 'ensembl_id': 0},
#  'ACAT2': {'Synonyms': ['ACAT2'],
#   'ECN': '2.3.1.9',
#   'ensembl_id': 'ENSG00000120437'},
#  'AIFM3 ': {'Synonyms': ['AIFM3,', 'AIFL'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000183773'},
#  'ALDOC': {'Synonyms': ['ALDOC,', 'ALDC'],
#   'ECN': '4.1.2.13',
#   'ensembl_id': 'ENSG00000109107'},
#  'ATP5C1': {'Synonyms': ['ATP5F1C,', 'ATP5C,', 'ATP5C1,', 'ATP5CL1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000165629'},
#  'ATP5S': {'Synonyms': ['DMAC2,', 'ATP5SL'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000105341'},
#  'ATPAF1': {'Synonyms': ['TEX38,', 'ATPAF1-AS1,', 'C1ORF223,', 'THEG4'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000186118'},
#  'ATPAF2': {'Synonyms': ['ATPAF2,', 'ATP12,', 'ATP12P,', 'LP3663,', 'MC5DN1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000171953'},
#  'COX412': {'Synonyms': ['COX412'], 'ECN': 0, 'ensembl_id': 0},
#  'COX7A2L': {'Synonyms': ['COX7A2L,',
#    'COX7AR,',
#    'COX7RP,',
#    'EB1,',
#    'SCAF1,',
#    'SCAFI,',
#    'SIG81'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000115944'},
#  'CPTIB': {'Synonyms': ['CPTIB'], 'ECN': 0, 'ensembl_id': 0},
#  'DLST': {'Synonyms': ['DLST,', 'DLTS,', 'KGD2,', 'PGL7'],
#   'ECN': '2.3.1.61',
#   'ensembl_id': 'ENSG00000119689'},
#  'FBP2': {'Synonyms': ['KHSRP,', 'FBP2,', 'FUBP2,', 'KSRP,', 'P75'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000088247'},
#  'FOXRED2': {'Synonyms': ['FOXRED2,', 'ERFAD'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000100350'},
#  'G6PC': {'Synonyms': ['G6PC1,',
#    'G6PC,',
#    'G6PT,',
#    'G6PASE,',
#    'GSD1,',
#    'GSD1A'],
#   'ECN': '3.1.3.9',
#   'ensembl_id': 'ENSG00000131482'},
#  'GFPT1': {'Synonyms': ['GFPT1,',
#    'CMS12,',
#    'CMSTA1,',
#    'GFA,',
#    'GFAT,',
#    'GFAT_1,',
#    'GFAT1,',
#    'GFAT1M,',
#    'GFPT,',
#    'GFPT1L,',
#    'MSLG'],
#   'ECN': '2.6.1.16',
#   'ensembl_id': 'ENSG00000198380'},
#  'GSK3A': {'Synonyms': ['GSK3A'],
#   'ECN': '2.7.11.26',
#   'ensembl_id': 'ENSG00000105723'},
#  'GYS2': {'Synonyms': ['GYS2'],
#   'ECN': '2.4.1.11',
#   'ensembl_id': 'ENSG00000111713'},
#  'HARS2': {'Synonyms': ['HARS2,',
#    'HARSL,',
#    'HARSR,',
#    'HO3,',
#    'HISRS,',
#    'PRLTS2'],
#   'ECN': '6.1.1.21',
#   'ensembl_id': 'ENSG00000112855'},
#  'HSPA13': {'Synonyms': ['HSPA13,', 'STCH'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000155304'},
#  'ISCA2': {'Synonyms': ['ISCA2,', 'HBLD1,', 'ISA2,', 'MMDS4,', 'C14_5557'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000165898'},
#  'LOC620306 ': {'Synonyms': ['LOC620306 '], 'ECN': 0, 'ensembl_id': 0},
#  'MDH1B': {'Synonyms': ['MDH1B,', 'RP11-95H11'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000138400'},
#  'MRPL19': {'Synonyms': ['MRPL19,',
#    'L19MT,',
#    'MRP-L15,',
#    'MRP-L19,',
#    'MRPL15,',
#    'RLX1,',
#    'RPML15'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000115364'},
#  'MRPL21': {'Synonyms': ['MRPL21,', 'L21MT,', 'MRP-L21'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000197345'},
#  'MRPL35': {'Synonyms': ['MRPL35,', 'L35MT,', 'MRP-L35'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000132313'},
#  'MRPS14': {'Synonyms': ['MRPS14,',
#    'COXPD38,',
#    'DJ262D12.2,',
#    'HSMRPS14,',
#    'MRP-S14,',
#    'S14MT'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000120333'},
#  'MRPS27': {'Synonyms': ['MRPS27,', 'MRP-S27,', 'S27MT'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000113048'},
#  'MTCH1': {'Synonyms': ['MTCH1,', 'CGI-64,', 'PIG60,', 'PSAP,', 'SLC25A49'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000137409'},
#  'NDUFS1': {'Synonyms': ['NDUFS1,',
#    'CI-75KD,',
#    'CI-75K,',
#    'MC1DN5,',
#    'PRO1304'],
#   'ECN': '7.1.1.2',
#   'ensembl_id': 'ENSG00000023228'},
#  'NO01': {'Synonyms': ['NO01'], 'ECN': 0, 'ensembl_id': 0},
#  'OGFOD2': {'Synonyms': ['OGFOD2'], 'ECN': 0, 'ensembl_id': 'ENSG00000111325'},
#  'OXGRI': {'Synonyms': ['OXGRI'], 'ECN': 0, 'ensembl_id': 0},
#  'OXSM': {'Synonyms': ['OXSM,', 'CEM1,', 'FASN2D,', 'KASI,', 'KS'],
#   'ECN': '2.3.1.179',
#   'ensembl_id': 'ENSG00000151093'},
#  'PCK2': {'Synonyms': ['PCK2,', 'PEPCK,', 'PEPCK-M,', 'PEPCK2'],
#   'ECN': '4.1.1.32',
#   'ensembl_id': 'ENSG00000100889'},
#  'PFKFB3': {'Synonyms': ['PFKFB3,', 'IPFK2,', 'PFK2,', 'IPFK-2'],
#   'ECN': '2.7.1.105 3.1.3.46',
#   'ensembl_id': 'ENSG00000170525'},
#  'POR': {'Synonyms': ['POR'], 'ECN': 0, 'ensembl_id': 0},
#  'PPARG': {'Synonyms': ['PERM1,', 'C1ORF170'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000187642'},
#  'PPARGC1A': {'Synonyms': ['PPARGC1A,',
#    'LEM6,',
#    'PGC-1(ALPHA),',
#    'PGC-1ALPHA,',
#    'PGC-1V,',
#    'PGC1,',
#    'PGC1A,',
#    'PPARGC1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000109819'},
#  'SLC25A21': {'Synonyms': ['SLC25A21,', 'MTDPS18,', 'ODC,', 'ODC1'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000183032'},
#  'SLC2A12 ': {'Synonyms': ['SLC2A12,', 'GLUT12,', 'GLUT8'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000146411'},
#  'SLC2A13': {'Synonyms': ['SLC2A13,', 'HMIT'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000151229'},
#  'SLC2A6': {'Synonyms': ['SLC2A6,', 'GLUT6,', 'GLUT9,', 'HSA011372'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000160326'},
#  'SLC37A4 ': {'Synonyms': ['SLC37A4,',
#    'CDG2W,',
#    'G6PT,',
#    'G6PT1,',
#    'G6PT2,',
#    'G6PT3,',
#    'GSD1B,',
#    'GSD1C,',
#    'GSD1D,',
#    'PRO0685,',
#    'SPX4,',
#    'TRG-19,',
#    'TRG19'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000137700'},
#  'SORDL': {'Synonyms': ['SORDL'], 'ECN': 0, 'ensembl_id': 0},
#  'Timm8a2': {'Synonyms': ['TIMM8A2'], 'ECN': 0, 'ensembl_id': 0},
#  'Tmed11': {'Synonyms': ['TMED11'], 'ECN': 0, 'ensembl_id': 0},
#  'TMEM59L': {'Synonyms': ['TMEM59L,', 'BSMAP,', 'C19ORF4'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000105696'},
#  'UCP3': {'Synonyms': ['UCP3,', 'SLC25A9'],
#   'ECN': 0,
#   'ensembl_id': 'ENSG00000175564'}}

# %%
# Checks model's reactions with no information on Genes, EC number and Ensembl ID

for gene in dict_synonyms:
    for synonym in dict_synonyms[gene]['Synonyms']:
        if synonym in names_to_check:
            print(f"{gene} found in model as {synonym}")

# %%
final_list = {}

for reaction in dict_model:
    # checks synonyms
    for gene_model in dict_model[reaction]['genes']:
        for gene_check in dict_synonyms:
            if gene_model in dict_synonyms[gene_check]['Synonyms']:
                if gene_check in final_list:
                    if reaction not in final_list[gene_check]:
                        final_list[gene_check].append(reaction)
                else:
                    final_list[gene_check] = [reaction]
                print(f"{gene_check} found in model as {reaction}({gene_model})")
    
    # checks EC number
    for gene_check in dict_synonyms:
        if dict_synonyms[gene_check]['ECN'] in dict_model[reaction]['ECN']:
            if gene_check in final_list:
                if reaction not in final_list[gene_check]:
                    final_list[gene_check].append(reaction)
            else:
                final_list[gene_check] = [reaction]
            print(f"{gene_check} found in model as {reaction}({dict_synonyms[gene_check]['ECN']})")

    # checks Ensembl ID
    for gene_check in dict_synonyms:
        if dict_synonyms[gene_check]['ensembl_id'] in dict_model[reaction]['ensembl_id']:
            if gene_check in final_list:
                if reaction not in final_list[gene_check]:
                    final_list[gene_check].append(reaction)
            else:
                final_list[gene_check] = [reaction]
            print(f"{gene_check} found in model as {reaction}({dict_synonyms[gene_check]['ensembl_id']})")
# Out:
# G6PC found in model as G6PPer(3.1.3.9)
# G6PC found in model as G6PPer(ENSG00000131482)
# ALDOC found in model as FBA(4.1.2.13)
# ALDOC found in model as FBA(ENSG00000109107)
# PCK2 found in model as PEPCK(4.1.1.32)
# DLST found in model as AKGDm(2.3.1.61)
# DLST found in model as AKGDm(ENSG00000119689)
# NDUFS1 found in model as CI_MitoCore(ENSG00000023228)
# COX6A2 found in model as CIV_MitoCore(ENSG00000156885)
# COX7A2L found in model as CIV_MitoCore(ENSG00000115944)
# ATP5C1 found in model as CV_MitoCore(ENSG00000165629)
# PCK2 found in model as PEPCKm(4.1.1.32)
# PCK2 found in model as PEPCKm(ENSG00000100889)
# ACAA1 found in model as MTPC16_MitoCore(2.3.1.16)
# ACAA1 found in model as MTPC14_MitoCore(2.3.1.16)
# ACAA1 found in model as r0724(2.3.1.16)
# ACAA1 found in model as r0634(2.3.1.16)
# ACAA1 found in model as r0732(2.3.1.16)
# ACAA1 found in model as r0287(2.3.1.16)
# ACAT2 found in model as ACACT1rm(2.3.1.9)
# ACAA1 found in model as ACACT10m(2.3.1.16)
# ACSS2 found in model as ACCOALm(6.2.1.1)
# SLC25A21 found in model as 2OXOADPTmB_MitoCore(ENSG00000183032)
# SLC25A21 found in model as 2OXOADPTmC_MitoCore(ENSG00000183032)
# DLST found in model as 2OXOADOXm(2.3.1.61)
# DLST found in model as 2OXOADOXm(ENSG00000119689)
# SLC25A21 found in model as 2AMADPTmB_MitoCore(ENSG00000183032)
# SLC25A21 found in model as 2AMADPTmC_MitoCore(ENSG00000183032)
# SLC25A21 found in model as ORNDC(ODC1)
# CKB found in model as CKc(CKB)
# ACSS2 found in model as ACSm(6.2.1.1)
# ACSS2 found in model as ACS(6.2.1.1)
# ACSS2 found in model as ACS(ENSG00000131069)
# UCP3 found in model as HtmB_MitoCore(ENSG00000175564)

# %%
final_list
# Out:
# {'G6PC': ['G6PPer'],
#  'ALDOC': ['FBA'],
#  'PCK2': ['PEPCK', 'PEPCKm'],
#  'DLST': ['AKGDm', '2OXOADOXm'],
#  'NDUFS1': ['CI_MitoCore'],
#  'COX6A2': ['CIV_MitoCore'],
#  'COX7A2L': ['CIV_MitoCore'],
#  'ATP5C1': ['CV_MitoCore'],
#  'ACAA1': ['MTPC16_MitoCore',
#   'MTPC14_MitoCore',
#   'r0724',
#   'r0634',
#   'r0732',
#   'r0287',
#   'ACACT10m'],
#  'ACAT2': ['ACACT1rm'],
#  'ACSS2': ['ACCOALm', 'ACSm', 'ACS'],
#  'SLC25A21': ['2OXOADPTmB_MitoCore',
#   '2OXOADPTmC_MitoCore',
#   '2AMADPTmB_MitoCore',
#   '2AMADPTmC_MitoCore',
#   'ORNDC'],
#  'CKB': ['CKc'],
#  'UCP3': ['HtmB_MitoCore']}

# %% [markdown]
# dict_synonym = {symbol : {synonym: [], ECN: "", ID: ""}}
#
# dict_model = {reaction : {genes: [], ECN: [], ID:[]}}
